# %% [markdown]
# # NSQIP - Random Forests
# ---
#
# We'll use Random Forests here to build a classifier. The idea behind Random Forests is to fit many decision trees to bootstrap samples of the data. This prevents over-fitting. Our strategy will be:
#  - Divide the data into training and testing sets.
#  - Choose Random Forest hyper-parameters via cross validation.
#  - Fit a Random Forest to the training set with the best hyper-parameters.
#  - Check performance on the testing set.

# %% [markdown]
# Begin with imports of key libraries, and load the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import Imputer
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.grid_search import GridSearchCV
import sklearn.metrics as sklm
import random
import warnings 
import math
# warnings.filterwarnings("ignore") # Ignore annoying warnings

dataDir = './Data/'
mungedFileName = dataDir + 'mungedData.pkl'

cdf = pd.read_pickle(mungedFileName)

# %% [markdown]
# Next, determine which CPT codes we'll use.

# %%
# CPT codes were munged to numeric values
CPTcodes = cdf.loc[:,'CPT']

# Print some data on all case categories in our dataset
print('--- Achilles operative repair ---')
keepCPT = [27650,27652,27654]
caseCounts = [(eachCPT, list(CPTcodes).count(eachCPT)) for eachCPT in keepCPT]
for aCPT, aCount in caseCounts:
    print('CPT: %d Cases: %d' % (aCPT, aCount))
print('--- Total: %d ---\n' % sum([each[1] for each in caseCounts]))
    

print('--- Calcaneus operative repair ---')
keepCPT = [28406,28415,28420] 
caseCounts = [(eachCPT, list(CPTcodes).count(eachCPT)) for eachCPT in keepCPT]
for aCPT, aCount in caseCounts:
    print('CPT: %d Cases: %d' % (aCPT, aCount))
print('--- Total: %d ---\n' % sum([each[1] for each in caseCounts]))


print('--- Ankle Fractures ---')
keepCPT = [27766, 27769, 27792, 27814, 27822, 27823, 27826, 27827, 27828, 27829]
caseCounts = [(eachCPT, list(CPTcodes).count(eachCPT)) for eachCPT in keepCPT]
for aCPT, aCount in caseCounts:
    print('CPT: %d Cases: %d' % (aCPT, aCount))
print('--- Total: %d ---\n' % sum([each[1] for each in caseCounts]))

# Choose a specific group of CPT codes to keep, and select them from the data table
keepCPT = [27766, 27769, 27792, 27814, 27822, 27823, 27826, 27827, 27828, 27829]
# keepCPT = [27650,27652,27654]
cdf = cdf.loc[cdf['CPT'].isin(keepCPT)]
# Out:
# --- Achilles operative repair ---
# CPT: 27650 Cases: 1576
# CPT: 27652 Cases: 106
# CPT: 27654 Cases: 288
# --- Total: 1970 ---
#
# --- Calcaneus operative repair ---
# CPT: 28406 Cases: 0
# CPT: 28415 Cases: 0
# CPT: 28420 Cases: 50
# --- Total: 50 ---
#
# --- Ankle Fractures ---
# CPT: 27766 Cases: 688
# CPT: 27769 Cases: 74
# CPT: 27792 Cases: 3409
# CPT: 27814 Cases: 3910
# CPT: 27822 Cases: 2076
# CPT: 27823 Cases: 594
# CPT: 27826 Cases: 99
# CPT: 27827 Cases: 561
# CPT: 27828 Cases: 631
# CPT: 27829 Cases: 630
# --- Total: 12672 ---

# %% [markdown]
# Print out a list of all the potential predictor columns we could use.

# %%
for col in cdf.columns:
    print(col)
# Out:
# ADMQTR-1
# ADMQTR-2
# ADMQTR-3
# ADMQTR-4
# ADMSYR-2007.0
# ADMSYR-2008.0
# ADMSYR-2009.0
# ORGSPCSSI-Organ/Space SSI
# OSSIPATOS-Yes
# OTHBLEED-No Complication
# OTHBLEED-Transfusions/Intraop/Postop
# OTHDVT-DVT Requiring Therap
# OTHDVT-DVT Requiring Therapy
# OTHDVT-No Complication
# OTHERCPT10-27691.0
# OTHERCPT10-28270.0
# OTHERCPT3
# OTHERCPT4
# OTHERCPT5
# OTHERCPT6
# OTHERCPT7
# OTHERCPT8-27640.0
# OTHERCPT8-27687.0
# OTHERCPT8-27690.0
# OTHERCPT8-27871.0
# OTHERCPT8-28208.0
# OTHERCPT8-28285.0
# OTHERCPT8-28290.0
# OTHERCPT8-28306.0
# OTHERCPT9-27698.0
# OTHERCPT9-28208.0
# OTHERCPT9-28285.0
# OTHERCPT9-28300.0
# OTHERCPT9-28308.0
# OTHERPROC10-CAPSUL MTTARPHLNGL JT +-TENORRHAPHY EA JT SPX
# OTHERPROC10-TR/TRNSPL 1 TDN W/MUSC REDIRION/REROUTING DP
# OTHERPROC7-APPLICATION SHORT LEG SPLINT CALF FOOT
# OTHERPROC7-ARTHROTOMY W/SYNOVECTOMY ANKLE
# OTHERPROC7-BONE GRAFT ANY DONOR AREA MINOR/SMALL
# OTHERPROC7-CORRECTION HAMMERTOE
# OTHERPROC7-GASTROCNEMIUS RECESSION
# OTHERPROC7-IMADM PRQ ID SUBQ/IM NJXS 1 VACCINE
# OTHERPROC7-INJECTION ANES OTHER PERIPHERAL NERVE/BRANCH
# OTHERPROC7-NEG PRESS WND THER </EQUAL 50 SQ CM
# OTHERPROC7-OSTEOT W/WO LNGTH SHRT/CORRJ 1ST METAR
# OTHERPROC7-OSTEOT W/WO LNGTH SHRT/CORRJ METAR XCP 1ST EA
# OTHERPROC7-OSTEOTOMY CALCANEUS +-INTERNAL FIXATION
# OTHERPROC7-OSTEOTOMY TARSAL BONES OTH/THN CALCANEUS/TALUS
# OTHERPROC7-PRTL EXC B1 TALUS/CALCANEUS
# OTHERPROC7-REPAIR TENDON EXTENSOR FOOT 1/2 EACH TENDON
# OTHERPROC7-TENOTOMY PRQ ACHILLES TENDON SPX GENERAL ANES
# OTHERPROC7-TISSUE GRAFTS OTHER
# OTHERPROC7-TX OPN TDN FLXR TOE 1 TDN SPX
# OTHERPROC8-ARTHRODESIS TIBIOFIBULAR JOINT PROXIMAL/DISTAL
# OTHERPROC8-CORRECTION HAMMERTOE
# OTHERPROC8-CORRJ HALLUX VALGUS W/WO SESMDC SMPL EXOSTECTOMY
# OTHERPROC8-GASTROCNEMIUS RECESSION
# OTHERPROC8-OSTEOT W/WO LNGTH SHRT/CORRJ 1ST METAR
# OTHERPROC8-PARTIAL EXCISION BONE TIBIA
# OTHERPROC8-REPAIR TENDON EXTENSOR FOOT 1/2 EACH TENDON
# OTHERPROC8-TR/TRNSPL 1 TDN W/MUSC REDIRION/REROUTING SUPFC
# OTHERPROC9-CORRECTION HAMMERTOE
# OTHERPROC9-OSTEOT +-LNGTH SHRT/CORRJ METAR XCP 1ST EA
# OTHERPROC9-OSTEOT W/WO LNGTH SHRT/CORRJ METAR XCP 1ST EA
# OTHERPROC9-OSTEOTOMY CALCANEUS +-INTERNAL FIXATION
# OTHERPROC9-REPAIR SECONDARY DISRUPTED LIGAMENT ANKLE COLTRL
# OTHERPROC9-REPAIR TENDON EXTENSOR FOOT 1/2 EACH TENDON
# OTHERWRVU1
# OTHERWRVU10-10.49
# OTHERWRVU10-4.93
# OTHERWRVU2
# OTHERWRVU3
# OTHERWRVU4
# OTHERWRVU5
# OTHERWRVU6
# OTHERWRVU7
# OTHERWRVU8-12.24
# OTHERWRVU8-4.51
# OTHERWRVU8-5.62
# OTHERWRVU8-5.83
# OTHERWRVU8-6.0
# OTHERWRVU8-6.41
# OTHERWRVU8-9.17
# OTHERWRVU8-9.54
# OTHERWRVU9-4.51
# OTHERWRVU9-5.48
# OTHERWRVU9-5.62
# OTHERWRVU9-9.61
# OTHERWRVU9-9.73
# OTHGRAFL-Graft/Prosthesis/Flap Failure
# OTHGRAFL-No Complication
# OTHSESHOCK-No Complication
# OTHSESHOCK-Septic Shock
# OTHSYSEP-No Complication
# OTHSYSEP-Sepsis
# OUPNEUMO-No Complication
# OUPNEUMO-Pneumonia
# PACKS
# PARA-Yes
# PGY
# PNAPATOS-Yes
# PODIAG_OTHER10-T88.6XXA
# PRALBUM
# PRALKPH
# PRBILI
# PRBUN
# PRCREAT
# PREGNANCY-Yes
# PRHCT
# PRINR
# PROPER30-Yes
# PRPLATE
# PRPT
# PRPTT
# PRSEPIS-None
# PRSEPIS-SIRS
# PRSEPIS-Sepsis
# PRSEPIS-Septic Shock
# PRSGOT
# PRSODM
# PRVPCI-Yes
# PRVPCS-Yes
# PRWBC
# PULEMBOL-No Complication
# PULEMBOL-Pulmonary Embolism
# QUAD-Yes
# RACE_NEW-American Indian or Alaska Native
# RACE_NEW-Asian
# RACE_NEW-Black or African American
# RACE_NEW-Native Hawaiian or Pacific Islander
# RACE_NEW-Unknown
# RACE_NEW-Unknown/Not Reported
# RACE_NEW-White
# RADIO-Yes
# RBC
# READMISSION-Yes
# READMISSION1-Yes
# READMISSION2-Yes
# READMPODAYS1
# READMPODAYS2
# READMRELATED1-Yes
# READMRELATED2-Yes
# READMRELICD101-S89.399A
# READMRELICD92-560.1
# READMRELICD92-780.6
# READMSUSPREASON1-Acute Renal Failure
# READMSUSPREASON1-DVT Requiring Therapy
# READMSUSPREASON1-Deep Incisional SSI
# READMSUSPREASON1-Graft/Prosthesis/Flap Failure
# READMSUSPREASON1-Myocardial Infarction
# READMSUSPREASON1-Organ/Space SSI
# READMSUSPREASON1-Other (list ICD 10 code)
# READMSUSPREASON1-Other (list ICD 9 code)
# READMSUSPREASON1-Pneumonia
# READMSUSPREASON1-Pulmonary Embolism
# READMSUSPREASON1-Sepsis
# READMSUSPREASON1-Septic Shock
# READMSUSPREASON1-Superficial Incisional SSI
# READMSUSPREASON1-Unplanned Intubation
# READMSUSPREASON1-Urinary Tract Infection
# READMSUSPREASON1-Vein Thrombosis Requiring Therapy
# READMSUSPREASON1-Wound Disruption
# READMSUSPREASON2-DVT Requiring Therapy
# READMSUSPREASON2-Deep Incisional SSI
# READMSUSPREASON2-Other (list ICD 9 code)
# READMSUSPREASON2-Superficial Incisional SSI
# READMSUSPREASON2-Wound Disruption
# READMUNRELICD101-C78.5
# READMUNRELICD101-K29.0
# READMUNRELICD101-R62.7
# READMUNRELICD92-291.81
# READMUNRELICD92-401.9
# READMUNRELICD92-486.0
# READMUNRELICD92-586.0
# READMUNRELICD92-8.45
# READMUNRELSUSP1-Acute Renal Failure
# READMUNRELSUSP1-Deep Incisional SSI
# READMUNRELSUSP1-Myocardial Infarction
# READMUNRELSUSP1-Organ/Space SSI
# READMUNRELSUSP1-Other (list ICD10 code)
# READMUNRELSUSP1-Other (list ICD9 code)
# READMUNRELSUSP1-Pneumonia
# READMUNRELSUSP1-Urinary Tract Infection
# READMUNRELSUSP2-Other (list ICD9 code)
# REINTUB-No Complication
# REINTUB-Unplanned Intubation
# RENAFAIL-Yes
# RENAINSF-No Complication
# RENAINSF-Progressive Renal Insufficiency
# REOPERATION-Yes
# REOPERATION1-Yes
# REOPERATION2-Yes
# REOPERATION3-Yes
# REOPOR1ICD101-T81.4XXA
# REOPOR1ICD101-Z86.31
# REOPOR2CPT1
# REOPOR2ICD91-41.11
# REOPOR2ICD91-733.8
# REOPOR2ICD91-824.5
# REOPOR2ICD91-958.92
# REOPOR2ICD91-996.49
# REOPOR2ICD91-996.67
# REOPOR2ICD91-997.6
# REOPOR2ICD91-998.3
# REOPOR2ICD91-998.32
# REOPOR2ICD91-998.5
# REOPOR2ICD91-998.59
# REOPORCPT1
# RESTPAIN-Yes
# RETOR2PODAYS
# RETOR2RELATED-No
# RETOR2RELATED-Unknown
# RETOR2RELATED-Yes
# RETORPODAYS
# RETORRELATED-No
# RETORRELATED-Unknown
# RETORRELATED-Yes
# RETURNOR-Yes
# SDISDT-2008.0
# SDISDT-2009.0
# SDISDT-2010.0
# SEPSHOCKPATOS-Yes
# SEPSISPATOS-Yes
# SEX-female
# SEX-male
# SMOKE-Yes
# SSSIPATOS-Yes
# STEROID-Yes
# STILLINHOSP-Yes
# STOODAY
# SUPINFEC-No Complication
# SUPINFEC-Superficial Incisional SSI
# SURGANE
# TOTHLOS
# TOTSLOS
# TRANSFUS-Yes
# TRANST-Acute Care Hospital
# TRANST-Admitted directly from home
# TRANST-Chronic Care Facility
# TRANST-From acute care hospital inpatient
# TRANST-Not transferred (admitted from home)
# TRANST-Nursing home - Chronic care - Intermediate care
# TRANST-Other
# TRANST-Outside emergency department
# TRANST-Transfer from other
# TRANST-Unknown
# TRANST-VA Acute Care Hospital
# TUMORCNS-Yes
# TYPEINTOC-Unplanned Intubation
# UNPLANNEDREADMISSION1-Yes
# UNPLANNEDREADMISSION2-Yes
# UNPLANREADMISSION-Yes
# URNINFEC-No Complication
# URNINFEC-Urinary Tract Infection
# UTIPATOS-Yes
# VENTILAT-Yes
# VENTPATOS-Yes
# WEIGHT
# WNDCLAS-1-Clean
# WNDCLAS-2-Clean/Contaminated
# WNDCLAS-3-Contaminated
# WNDCLAS-4-Dirty/Infected
# WNDINF-Yes
# WNDINFD-Deep Incisional SSI
# WNDINFD-No Complication
# WORKRVU
# WOUND_CLOSURE-All layers of incision (deep and superficial) fully closed
# WOUND_CLOSURE-No layers of incision are surgically closed
# WOUND_CLOSURE-Only deep layers closed; superficial left open
# WTLOSS-Yes
# YRDEATH-2008.0
# YRDEATH-2009.0
# YRDEATH-2010.0
# YRDEATH-2011.0
# YRDEATH-2012.0
# YRDEATH-2013.0
# YRDEATH-2014.0
# YRDEATH-2015.0

# %% [markdown]
# Decide which outcome we'll look at.

# %%
# y is True for bad things happening.
# 'mortality', 'major', 'minor', 'bleeding', 'readmit'
from outcomeVariables import getOutcomeVariable
yFull = getOutcomeVariable(cdf, 'readmit')

# %% [markdown]
# Count how many of each outcome occurence there were:

# %%
np.count_nonzero(yFull)
# Out:
# 48

# %% [markdown]
# Next, determine which response and predictor columns we want to use. We're going to drop any rows that don't have outcome data for the outcome we're looking at. (For these composite complication outcomes, we've assumed that missing data means the complication didn't happen. Since these complications are rare, even if this is wrong it's a good guess and unlikely to matter much.)

# %%
# Drop rows with NaN outcome y data
nanIdx = np.isnan(yFull).nonzero()
yFull = np.delete(yFull.ravel(), nanIdx ,axis=0).reshape(-1,1)
cdf.drop(cdf.index[nanIdx], axis=0, inplace=True)

# Make a column for transfer from any facility
cdf.loc[:,'TRANST-FACILITY'] = 1 - cdf.loc[:,'TRANST-Admitted directly from home'] -\
                                cdf.loc[:,'TRANST-Not transferred (admitted from home)'] -\
                                cdf.loc[:,'TRANST-Unknown']
# Make a column for elderly
cdf.loc[:,'ELDERLY-Yes'] = (cdf['AGE'] >= 80).astype(int)
# Make a column for non-General Anesthesia
cdf.loc[:,'ANESTHES-NonGA'] = 1 - cdf.loc[:,'ANESTHES-General']
# Add a BMI column
cdf.loc[:,'BMI'] = cdf.loc[:,'WEIGHT']*(1/2.20462)/(cdf.loc[:,'HEIGHT']*(1/39.3701)*\
                                                    cdf.loc[:,'HEIGHT']*(1/39.3701))
# Add a all DIABETES column
cdf.loc[:,'DIABETES-Yes'] = 1 - cdf.loc[:,'DIABETES-NO']
# Pulmonary abnormalities, score is higher if both COPD and pneumonia
cdf.loc[:,'PULMHX'] = cdf.loc[:,'HXCOPD-Yes'] + cdf.loc[:,'CPNEUMON-Yes']
# Cardiac abnormalities, score is higher with multiple
cdf.loc[:,'CARDSHX'] = cdf.loc[:,'HXCHF-Yes'] + cdf.loc[:,'HXMI-Yes'] + \
                    cdf.loc[:,'PRVPCI-Yes'] + cdf.loc[:,'PRVPCS-Yes'] + \
                    cdf.loc[:,'HXANGINA-Yes']
# Renal abnormalities
cdf.loc[:,'RENALHX'] = cdf.loc[:,'RENAFAIL-Yes'] + cdf.loc[:,'DIALYSIS-Yes']
# CNS abnormalities
cdf.loc[:,'CNSHX'] = cdf.loc[:,'HXTIA-Yes'] + cdf.loc[:,'CVA-Yes'] + cdf.loc[:,'CVANO-Yes']
# ASA Class
cdf.loc[:,'ASACLASS-345'] = cdf.loc[:,'ASACLAS-3-Severe Disturb'] + \
                cdf.loc[:,'ASACLAS-4-Life Threat'] + cdf.loc[:,'ASACLAS-5-Moribund']
# Operative time
cdf.loc[:,'LONGTIME'] = (cdf.loc[:,'OPTIME'] >= 120).astype(int)



keepList = ['SEX-male','RACE_NEW-White','ETHNICITY_HISPANIC-Yes','TRANST-FACILITY','AGE',\
           'ELDERLY-Yes', 'ANESTHES-NonGA', 'BMI','DIABETES-Yes','ETOH-Yes','FNSTATUS2-Independent',\
           'PULMHX','CARDSHX','RENALHX', 'CNSHX','TRANSFUS-Yes','ASACLASS-345','OPTIME','LONGTIME']

# List of predictors to keep
keepList1 = ['SEX', 'RACE_NEW','ETHNICITY_HISPANIC','AGE','ANESTHES','HEIGHT','WEIGHT','BMI',\
             'DIABETES','SMOKE','PACKS','ETOH','DYSPNEA','FNSTATUS2','VENTILAT',\
             'HXCOPD','CPNEUMON','HXCHF','HXMI','PRVPCI','PRVPCS','HXANGINA','HYPERMED',\
             'HXPVD','RENAFAIL','DIALYSIS','CVA','DISCANCR','WNDINF-','STEROID','WTLOSS',\
             'BLEEDDIS','PROPER30','ASACLASS','FNSTATUS1','RBC']
# An additional list of predictors that might be interesting
keepList2 = ['ASCITES','PRSODM','PRBUN','PRCREAT','PRALBUM','PRBILI','PRSGOT','PRALKPH',\
             'PRWBC','PRHCT','PRPLATE','PRPTT','PRINR','PRPT','PGY','ESOVAR','RESTPAIN',\
             'HXTIA','TRANSFUS','CHEMO','RADIO','PRSEPSIS','PREGNANCY','EMERGNCY',\
             'OPTIME','MALLAMP']

# Combine the lists
# keepList = keepList1 + keepList2
# Make a list of any column in cdf whose name starts with a string in keepList
colsToKeep = [colName for colName in cdf.columns \
              if np.any([colName.startswith(keepItem) for keepItem in keepList])]
cdf = cdf[colsToKeep]

# %% [markdown]
# We're going to drop columns that only have one value in them. We're also going to replace any missing data in the predictor columns with the column mean. (Many of these methods fail on missing data.)

# %%
# Protect against only having one value in the columns.
# (Imputer will drop these columns, and then we won't know the names...)
for colName in cdf.columns:
    colData = cdf[colName]
    uniques = np.unique(colData)
    nonNanUniques = [item for item in uniques if ~np.isnan(item)]
    if len(nonNanUniques) < 2:
        print('Not enough variance, dropping column: %s' % colName)
        cdf.drop(colName, axis=1, inplace=True)

# Impute missing data in cdf
colNames = cdf.columns
imp = Imputer(missing_values='NaN', strategy='mean', axis=0, verbose=True)
imp.fit(cdf)
X = imp.transform(cdf)
cdf = pd.DataFrame(X, columns=colNames)

# %% [markdown]
# Print the predictor columns we're actually going to use:

# %%
for col in cdf.columns:
    print(col)
# Out:
# AGE
# ETHNICITY_HISPANIC-Yes
# ETOH-Yes
# FNSTATUS2-Independent
# OPTIME
# RACE_NEW-White
# SEX-male
# TRANSFUS-Yes
# TRANST-FACILITY
# ELDERLY-Yes
# ANESTHES-NonGA
# BMI
# DIABETES-Yes
# PULMHX
# CARDSHX
# RENALHX
# CNSHX
# ASACLASS-345
# LONGTIME

# %% [markdown]
# Since our regularization penalty is based on the size of the coefficients, we need to scale each column to have equal mean and variance. We don't need to add an intercept column; sklearn gives us an intercept as a fit option.

# %%
# Scale the columns
colNames = cdf.columns
X = StandardScaler().fit_transform(cdf)
scaledX = pd.DataFrame(X, columns=colNames)

# %% [markdown]
# We break the data into separate fractions for training (2/3) and testing (1/3). All of our fitting and cross-validation will be done on the training set. The testing set will be held out to evaluate the final model performance.

# %%
# Split for validation
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaledX, yFull, test_size=0.33)
y_train = y_train.reshape(-1,)
y_test = y_test.reshape(-1,)

# %% [markdown]
# Make a RFC with 1000 trees. Choose a variety of features by 5-fold cross validation.

# %%
rfc = RandomForestClassifier(n_estimators=1000)
tunedParam = 'max_depth'
# criterion: gini or entropy
# max_features: sqrt or log2
tuned_parameters = [{tunedParam: [2,3,4,5,6,8,10],\
                     'criterion': ['entropy'],\
                     'max_features': ['log2'],\
                     'oob_score': [True, False]}]
gscv = GridSearchCV(rfc,tuned_parameters,cv=5,scoring='roc_auc',verbose=1)
gscv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [Parallel(n_jobs=1)]: Done  49 tasks       | elapsed:  2.6min
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:  3.9min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid=[{'oob_score': [True, False], 'max_depth': [2, 3, 4, 5, 6, 8, 10], 'criterion': ['entropy'], 'max_features': ['log2']}],
#        pre_dispatch='2*n_jobs', refit=True, scoring='roc_auc', verbose=1)

# %%
gscv.grid_scores_
print('Best Params: ')
print(gscv.best_params_)
means = [mean_score for params, mean_score, scores in gscv.grid_scores_]
Cs = [params[tunedParam] for params, mean_score, scores in gscv.grid_scores_]
plt.plot(np.log10(Cs), means,'bo')
bestC = gscv.best_params_[tunedParam]
ylims = plt.gca().get_ylim()
plt.plot(np.log10([bestC, bestC]),ylims,color='k',ls=':')
plt.ylim(ylims)
plt.xlabel('$Log_{10}($' + tunedParam + '$)$')
plt.ylabel('Cross-validated AUC')
plt.show()
# Out:
# Best Params:
# {'oob_score': False, 'max_depth': 2, 'criterion': 'entropy', 'max_features': 'log2'}

# %% [markdown]
# Plot ROC curves for in-sample training data, and test data, for both the full and reduced model. The test data here was not used to fit the model at all, so it should approximate how our model will perform prospectively on new data. Furthermore, if we've done a good job regularizing, the in-sample performance should be pretty close to the test data performance.

# %%
# Plot an ROC curve for training
plt.clf
pred_train = gscv.predict_proba(X_train)[:,1]
rocAUC_train = sklm.roc_auc_score(y_train,pred_train)
print('In-sample ROC AUC = %.3f ' % rocAUC_train)
fpr, tpr, _ = sklm.roc_curve(y_train, pred_train)
plt.figure()
plt.plot(fpr,tpr,label='In-sample')

# Plot an ROC curve for test data
pred_test = gscv.predict_proba(X_test)[:,1]
rocAUC_test = sklm.roc_auc_score(y_test,pred_test)
print('Test ROC AUC = %.3f ' % rocAUC_test)
fpr, tpr, _ = sklm.roc_curve(y_test, pred_test)
plt.plot(fpr,tpr,label='Test')

# Format the ROC plot
plt.plot([0, 1], [0, 1], color='k', linestyle=':')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.gca().set_aspect('equal', adjustable='box')
plt.legend(loc='lower right')
plt.show()
# Out:
# In-sample ROC AUC = 0.865
# Test ROC AUC = 0.837
