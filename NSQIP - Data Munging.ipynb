# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing as pp
import warnings 
warnings.filterwarnings("ignore") # Ignore annoying warnings

dataDir = './Data/'
compiledFileName = dataDir + 'compiledData.pkl'
mungedFileName = dataDir + 'mungedData.pkl'

df = pd.read_pickle(compiledFileName)

# %% [markdown]
# The strategy should be:
# - Numeric items should be checked for numeracy, and kept as numbers. If there are non-numeric things we need to prompt for appropriate replacement. If there are only a few numbers, we actually probably want them as categories.
# - Items as text should be encoded as one-hot binary variables, and a LabelEncoder should be created for them.

# %%
# Utility function to see if a column has only real numeric values.
# NaN's are ok.
def numeracyCheck( column):
    nonNumerics = column[~column.apply(np.isreal)]
    if len(nonNumerics) > 0:
        print('\t Non-numeric values found at %d spots: ' % len(nonNumerics))
        print(pd.unique(nonNumerics))
        return False
    else:
        return True

# Utility function for encoding enumerated text as a collection of 
# one-hot binary vectors. This enumerates NaNs, so they don't show as
# missing data. We will reassign them as missing data.
def binarizeColumn( column):

    le = pp.LabelBinarizer(neg_label=0, pos_label=1, sparse_output=False)
    # Label binarizer will warn on NaNs
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
    #    column[pd.isnull(column)] = 'nan'
    uniqueVals = column.unique().tolist()
    print('\t Encoding %d enumerations: ' % len(uniqueVals))
    strVals = [str(n) for n in uniqueVals]
    le.fit(strVals)
    # print(le.classes_)
    y = le.transform(column.map(str))
    
    # If there are any classes matching 'nan'
    if ('nan' in le.classes_):
        print('\t Found enumerated NaNs...')
        nanCols = [index for index, aClass in enumerate(le.classes_) if aClass == 'nan' ]
        y = np.delete(y, nanCols, axis=1).astype(float)   # Delete the column in y
        le.classes_ = np.delete(le.classes_, nanCols)     # Delete the nan class label
        y[np.nonzero(pd.isnull(column)),:] = np.nan       # Set the nan rows to nan

    # Now check to see if our only remaining choices are 'Yes' and 'No'. If so, we only have to return 'Yes'    
    matchList = ['Yes', 'No']
    if all([any([leClass == target for target in matchList]) for leClass in le.classes_]):
        print('\t Binary response; returning only Yes')
        noCols = [index for index, aClass in enumerate(le.classes_) if aClass == 'No' ]
        y = np.delete(y, noCols, axis=1).astype(float)   # Delete the column in y
        le.classes_ = np.delete(le.classes_, noCols)   # Delete the No class label
        
    return y, le

# Force a column to be categorical
def forceCat( colName):
    matchList = ['CPT', 'PODIAG', 'ICD']
    force = any(ext in colName for ext in matchList)
    return force

# Utility function to determine whether a column should be numeric or categorical.
def numOrCat( column, colName):
    
    if forceCat( colName):
        print('\t Forced categorical based on name match.')
        return False

    numericThresh = 0.5  # Assume categorical if < numericThresh are numeric
    uniqueThresh  = 10   # Assume categorical if < uniqueThresh unique numbers

    nonNumerics = column[~column.apply(np.isreal) & ~column.apply(pd.isnull)]
    numerics    = column[column.apply(np.isreal) & ~column.apply(pd.isnull)]
    Nuniques = len(column.unique())

    if ((len(nonNumerics)/(len(numerics)+1)) > numericThresh) or (Nuniques < uniqueThresh):
        print('\t Column detected categorical.')
        return False
    else:
        print('\t Column detected numeric.')
        return True

# %% [markdown]
# Now we loop through all the columns in our existing DataFrame and make a clean version that has our appropriately cleaned and coded variables. Some of these variables are text fields (like procedure descriptions) that have many options. We'd need to do some feature extraction here to make this useful; for now we'll just leave these features out.
#
# This code should idenitfy any problems in the source DataFrame. I'll try to proactively address those by cleaning the data and giving a list of columns that should be forced categorical.

# %%
# Replace any '90+' age annotations with age 90.
df.loc[df['AGE'] == '90+','AGE'] = 90.0

# %%
# Make a clean DataFrame
cdf = pd.DataFrame()

for colName in df.columns:
    print('  ')
    print(colName)
    aColumn = df[colName]
    
    if len(aColumn.unique()) < 2:
        print('\t Skipping because there is only 1 value.')
        continue
    
    # If it looks numeric and isn't in our list to force categorical...
    if numOrCat(aColumn, colName):
        # If it's numeric
        if numeracyCheck(aColumn):
            # The column is a clean numeric column (but could have NaNs)
            nNaNs = sum(aColumn.isnull())
            print('\t Number NaN: %d' % nNaNs)
            
            # Add it to the clean DataFrame
            cdf[colName] = aColumn         
        else:
            # We need to clean it up
            print('*** Clean This Up ***')
    else:
        # If it needs to be categorical
        y, le = binarizeColumn(aColumn)
        nEnums = y.shape[1]
        if (nEnums <= 20):
            print(le.classes_)
            for binColN in np.arange(y.shape[1]):
                subColName = colName + '-' + le.classes_[binColN]
                cdf[subColName] = y[:,binColN]
        else:
            
            print('\t Skipping due to %d enums.' % nEnums)
# Out:
#
# ADMQTR
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# ['1' '2' '3' '4']
#
# ADMSYR
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# ['2007.0' '2008.0' '2009.0']
#
# ADMYR
# 	 Column detected categorical.
# 	 Encoding 8 enumerations:
# ['2007' '2008' '2009' '2010' '2011' '2012' '2013' '2014']
#
# AGE
# 	 Column detected numeric.
# 	 Number NaN: 0
#
# AIRTRA
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# ['Lip laceration or hematoma' 'None' 'Tooth chipped, loosened or lost']
#
# ANESTHES
# 	 Column detected categorical.
# 	 Encoding 10 enumerations:
# 	 Found enumerated NaNs...
# ['Epidural' 'General' 'Local' 'MAC/IV Sedation' 'Monitored Anesthesia Care'
#  'None' 'Other' 'Regional' 'Spinal']
#
# ANESTHES_OTHER
# 	 Column detected categorical.
# 	 Encoding 18 enumerations:
# 	 Found enumerated NaNs...
# ['Epidural' 'Epidural,Regional' 'General' 'Local'
#  'Local,Monitored Anesthesia Care/IV Sedation' 'Local,Other'
#  'Monitored Anesthesia Care/IV Sedation' 'Other' 'Regional'
#  'Regional,Local' 'Regional,Monitored Anesthesia Care/IV Sedation'
#  'Regional,Other' 'Spinal' 'Spinal,Epidural' 'Spinal,Local'
#  'Spinal,Monitored Anesthesia Care/IV Sedation' 'Spinal,Regional']
#
# ANESURG
# 	 Column detected numeric.
# 	 Number NaN: 13062
#
# ANETIME
# 	 Column detected numeric.
# 	 Number NaN: 13052
#
# ASACLAS
# 	 Column detected categorical.
# 	 Encoding 7 enumerations:
# 	 Found enumerated NaNs...
# ['1-No Disturb' '2-Mild Disturb' '3-Severe Disturb' '4-Life Threat'
#  '5-Moribund' 'None assigned']
#
# ASCITES
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# ['Yes']
#
# ATTEND
# 	 Column detected categorical.
# 	 Encoding 7 enumerations:
# 	 Found enumerated NaNs...
# ['Attending & Resident in OR' 'Attending Alone'
#  'Attending Not Present, but Available' 'Attending in OR'
#  'Attending in OR Suite' 'Not entered']
#
# BLEEDDIS
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# ['Yes']
#
# CASEID
# 	 Column detected numeric.
# 	 Number NaN: 0
#
# CDARREST
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['Cardiac Arrest Requiring CPR' 'No Complication']
#
# CDMI
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['Myocardial Infarction' 'No Complication']
#
# CHEMO
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# CNSCOMA
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['Coma greater than 24 Hours' 'No Complication']
#
# CNSCVA
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['No Complication' 'Stroke/CVA']
#
# COMA
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# CONCPT1
# 	 Forced categorical based on name match.
# 	 Encoding 43 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 42 enums.
#
# CONCPT10
# 	 Forced categorical based on name match.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['11045.0']
#
# CONCPT2
# 	 Forced categorical based on name match.
# 	 Encoding 13 enumerations:
# 	 Found enumerated NaNs...
# ['11010.0' '12002.0' '13120.0' '15003.0' '15101.0' '15120.0' '20694.0'
#  '27691.0' '27792.0' '52000.0' '64445.0' '97605.0']
#
# CONCPT3
# 	 Forced categorical based on name match.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# ['11042.0' '11044.0' '15100.0' '28306.0']
#
# CONCPT4
# 	 Forced categorical based on name match.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# ['11045.0' '15101.0' '27659.0']
#
# CONCPT5
# 	 Forced categorical based on name match.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['11045.0' '27687.0']
#
# CONCPT6
# 	 Forced categorical based on name match.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['11045.0']
#
# CONCPT7
# 	 Forced categorical based on name match.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['11045.0']
#
# CONCPT8
# 	 Forced categorical based on name match.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['11045.0']
#
# CONCPT9
# 	 Forced categorical based on name match.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['11045.0']
#
# CONCURR1
# 	 Column detected categorical.
# 	 Encoding 43 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 42 enums.
#
# CONCURR10
# 	 Column detected categorical.
# 	 Encoding 6 enumerations:
# 	 Found enumerated NaNs...
# ['FLUOR PHYS TM > 1 HR ASSISTING NON-RAD PHYS'
#  'MUSC MYOCUTANEOUS/FASCIOCUTANEOUS FLAP LXTR'
#  'MUSCLE TRANSFER SHOULDER/UPPER ARM SINGLE'
#  'REMOVAL EXTERNAL FIXATION SYSTEM UNDER ANES'
#  'SPLIT AGRFT T/A/L 1ST 100 CM/</1% BDY INFT/CHLD']
#
# CONCURR2
# 	 Column detected categorical.
# 	 Encoding 13 enumerations:
# 	 Found enumerated NaNs...
# ['CYSTOURETHROSCOPY' 'DBRDMT W/RMVL FM FX&/DISLC SKIN&SUBQ TISSUS'
#  'INJECTION ANESTHETIC AGENT SCIATIC NRV SINGLE'
#  'NEGATIVE PRESSURE WOUND THERAPY </= 50 SQ CM'
#  'OPEN TX DISTAL FIBULAR FRACTURE LAT MALLEOLUS'
#  'PREP SITE TRUNK/ARM/LEG ADDL 100 SQ CM/1PCT'
#  'REMOVAL EXTERNAL FIXATION SYSTEM UNDER ANES'
#  'REPAIR COMPLEX SCALP/ARM/LEG 1.1-2.5 CM'
#  'SMPL REPAIR SCALP/NECK/AX/GENIT/TRUNK 2.6-7.5CM'
#  'SPLIT AGRFT F/S/N/H/F/G/M/D GT 1ST 100 CM<1 %'
#  'SPLIT AGRFT T/A/L EA 100 CM/EA 1% BDY INFT/CHLD'
#  'TR/TRNSPL 1 TDN W/MUSC REDIRION/REROUTING DP']
#
# CONCURR3
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# ['DEBRIDEMENT BONE MUSCLE &/FASCIA 20 SQ CM/<'
#  'DEBRIDEMENT SUBCUTANEOUS TISSUE 20 SQ CM/<'
#  'OSTEOT W/WO LNGTH SHRT/CORRJ 1ST METAR'
#  'SPLIT AGRFT T/A/L 1ST 100 CM/&/1% BDY INFT/CHLD']
#
# CONCURR4
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# ['DBRDMT SUBCUTANEOUS TISSUE EA ADDL 20 SQ CM'
#  'RPR FLEXOR TENDON LEG SECONDARY W/O GRAFT EACH'
#  'SPLIT AGRFT T/A/L EA 100 CM/EA 1% BDY INFT/CHLD']
#
# CONCURR5
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['DBRDMT SUBCUTANEOUS TISSUE EA ADDL 20 SQ CM' 'GASTROCNEMIUS RECESSION']
#
# CONCURR6
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['DBRDMT SUBCUTANEOUS TISSUE EA ADDL 20 SQ CM']
#
# CONCURR7
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['DBRDMT SUBCUTANEOUS TISSUE EA ADDL 20 SQ CM']
#
# CONCURR8
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['DBRDMT SUBCUTANEOUS TISSUE EA ADDL 20 SQ CM']
#
# CONCURR9
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['DBRDMT SUBCUTANEOUS TISSUE EA ADDL 20 SQ CM']
#
# CONWRVU1
# 	 Column detected numeric.
# 	 Number NaN: 19485
#
# CONWRVU10
# 	 Skipping because there is only 1 value.
#
# CONWRVU2
# 	 Column detected numeric.
# 	 Number NaN: 19521
#
# CONWRVU3
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# ['0.8' '4.1' '6.0' '9.9']
#
# CONWRVU4
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['1.72' '7.1']
#
# CONWRVU5
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['6.41']
#
# CONWRVU6
# 	 Skipping because there is only 1 value.
#
# CONWRVU7
# 	 Skipping because there is only 1 value.
#
# CONWRVU8
# 	 Skipping because there is only 1 value.
#
# CONWRVU9
# 	 Skipping because there is only 1 value.
#
# CPNEUMON
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# CPT
# 	 Forced categorical based on name match.
# 	 Encoding 62 enumerations:
# 	 Skipping due to 62 enums.
#
# CVA
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# CVANO
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# DCDARREST
# 	 Column detected numeric.
# 	 Number NaN: 19516
#
# DCDMI
# 	 Column detected numeric.
# 	 Number NaN: 19515
#
# DCNSCOMA
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['4.0']
#
# DCNSCVA
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# ['0.0' '10.0' '3.0' '4.0']
#
# DDEHIS
# 	 Column detected numeric.
# 	 Number NaN: 19461
#
# DEHIS
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['No Complication' 'Wound Disruption']
#
# DFAILWEAN
# 	 Column detected numeric.
# 	 Number NaN: 19501
#
# DIABETES
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# ['INSULIN' 'NO' 'NON-INSULIN' 'ORAL']
#
# DIALYSIS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# DISCANCR
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# ['Yes']
#
# DISCHDEST
# 	 Column detected categorical.
# 	 Encoding 9 enumerations:
# 	 Found enumerated NaNs...
# ['Expired' 'Facility Which was Home' 'Home' 'Rehab' 'Separate Acute Care'
#  'Skilled Care, Not Home' 'Unknown' 'Unskilled Facility Not Home']
#
# DNEURODEF
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['0.0' '13.0']
#
# DNR
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# DOPERTOD
# 	 Column detected numeric.
# 	 Number NaN: 19492
#
# DOPRENAFL
# 	 Column detected numeric.
# 	 Number NaN: 19522
#
# DOPTODIS
# 	 Column detected numeric.
# 	 Number NaN: 5
#
# DORGSPCSSI
# 	 Column detected numeric.
# 	 Number NaN: 19494
#
# DOTHBLEED
# 	 Column detected categorical.
# 	 Encoding 6 enumerations:
# 	 Found enumerated NaNs...
# ['0.0' '1.0' '2.0' '3.0' '6.0']
#
# DOTHDVT
# 	 Column detected numeric.
# 	 Number NaN: 19457
#
# DOTHGRAFL
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['14.0' '27.0']
#
# DOTHSESHOCK
# 	 Column detected numeric.
# 	 Number NaN: 19514
#
# DOTHSYSEP
# 	 Column detected numeric.
# 	 Number NaN: 19461
#
# DOUPNEUMO
# 	 Column detected numeric.
# 	 Number NaN: 19462
#
# DPATRM
# 	 Column detected numeric.
# 	 Number NaN: 13003
#
# DPRALBUM
# 	 Column detected numeric.
# 	 Number NaN: 14622
#
# DPRALKPH
# 	 Column detected numeric.
# 	 Number NaN: 14688
#
# DPRBILI
# 	 Column detected numeric.
# 	 Number NaN: 14718
#
# DPRBUN
# 	 Column detected numeric.
# 	 Number NaN: 8201
#
# DPRCREAT
# 	 Column detected numeric.
# 	 Number NaN: 7733
#
# DPRHCT
# 	 Column detected numeric.
# 	 Number NaN: 6813
#
# DPRINR
# 	 Column detected numeric.
# 	 Number NaN: 13323
#
# DPRNA
# 	 Column detected numeric.
# 	 Number NaN: 7813
#
# DPRPLATE
# 	 Column detected numeric.
# 	 Number NaN: 7174
#
# DPRPT
# 	 Column detected numeric.
# 	 Number NaN: 17887
#
# DPRPTT
# 	 Column detected numeric.
# 	 Number NaN: 14987
#
# DPRSGOT
# 	 Column detected numeric.
# 	 Number NaN: 14572
#
# DPRWBC
# 	 Column detected numeric.
# 	 Number NaN: 7140
#
# DPULEMBOL
# 	 Column detected numeric.
# 	 Number NaN: 19480
#
# DREINTUB
# 	 Column detected numeric.
# 	 Number NaN: 19493
#
# DRENAINSF
# 	 Column detected numeric.
# 	 Number NaN: 19520
#
# DSDTOHD
# 	 Column detected categorical.
# 	 Encoding 6 enumerations:
# 	 Found enumerated NaNs...
# ['0.0' '1.0' '15.0' '61.0' '7.0']
#
# DSSIPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# DSUPINFEC
# 	 Column detected numeric.
# 	 Number NaN: 19338
#
# DURNINFEC
# 	 Column detected numeric.
# 	 Number NaN: 19405
#
# DWNDINFD
# 	 Column detected numeric.
# 	 Number NaN: 19454
#
# DYSPNEA
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# ['AT REST' 'MODERATE EXERTION' 'No']
#
# ELECTSURG
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# ['No' 'Unknown' 'Yes']
#
# EMERGNCY
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# ['Yes']
#
# ESOVAR
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# ETHNICITY_HISPANIC
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# ['No' 'Unknown' 'Yes']
#
# ETOH
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# FAILWEAN
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['No Complication' 'On Ventilator greater than 48 Hours']
#
# FNSTATUS1
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# ['Independent' 'Partially Dependent' 'Totally Dependent']
#
# FNSTATUS2
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# ['Independent' 'Partially Dependent' 'Totally Dependent' 'Unknown']
#
# HDISDT
# 	 Column detected categorical.
# 	 Encoding 9 enumerations:
# 	 Found enumerated NaNs...
# ['2008.0' '2009.0' '2010.0' '2011.0' '2012.0' '2013.0' '2014.0' '2015.0']
#
# HEIGHT
# 	 Column detected numeric.
# 	 Number NaN: 1095
#
# HEMI
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# HTOODAY
# 	 Column detected numeric.
# 	 Number NaN: 2
#
# HXANGINA
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# HXCHF
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# ['Yes']
#
# HXCOPD
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# ['Yes']
#
# HXMI
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# HXPVD
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# HXTIA
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# HYPERMED
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# ['Yes']
#
# IMPSENS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# INOUT
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['Inpatient' 'Outpatient']
#
# MALLAMP
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# ['1.0' '2.0' '3.0' '4.0']
#
# MORBPROB
# 	 Column detected numeric.
# 	 Number NaN: 5950
#
# MORTPROB
# 	 Column detected numeric.
# 	 Number NaN: 5950
#
# NCDARREST
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# ['0' '1' '2']
#
# NCDMI
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# NCNSCOMA
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['0.0' '1.0']
#
# NCNSCVA
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# NDEHIS
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# NEURODEF
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['No Complication' 'Peripheral Nerve Injury']
#
# NFAILWEAN
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# NNEURODEF
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['0.0' '1.0']
#
# NOPRENAFL
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# NORGSPCSSI
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# NOTHBLEED
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# NOTHDVT
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# NOTHGRAFL
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['0.0' '1.0']
#
# NOTHSESHOCK
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# NOTHSYSEP
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# NOUPNEUMO
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# NPULEMBOL
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# NREINTUB
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# ['0' '1' '2']
#
# NRENAINSF
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# NSUPINFEC
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# NURNINFEC
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# ['0' '1' '2']
#
# NWNDINFD
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['0' '1']
#
# OPERYR
# 	 Column detected categorical.
# 	 Encoding 7 enumerations:
# ['2008' '2009' '2010' '2011' '2012' '2013' '2014']
#
# OPNOTE
# 	 Skipping because there is only 1 value.
#
# OPRENAFL
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['Acute Renal Failure' 'No Complication']
#
# OPTIME
# 	 Column detected numeric.
# 	 Number NaN: 3
#
# ORGSPCSSI
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['No Complication' 'Organ/Space SSI']
#
# OSSIPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# OTHBLEED
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['No Complication' 'Transfusions/Intraop/Postop']
#
# OTHDVT
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# ['DVT Requiring Therap' 'DVT Requiring Therapy' 'No Complication']
#
# OTHERCPT1
# 	 Forced categorical based on name match.
# 	 Encoding 407 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 406 enums.
#
# OTHERCPT10
# 	 Forced categorical based on name match.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['27691.0' '28270.0']
#
# OTHERCPT2
# 	 Forced categorical based on name match.
# 	 Encoding 306 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 305 enums.
#
# OTHERCPT3
# 	 Forced categorical based on name match.
# 	 Encoding 203 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 202 enums.
#
# OTHERCPT4
# 	 Forced categorical based on name match.
# 	 Encoding 120 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 119 enums.
#
# OTHERCPT5
# 	 Forced categorical based on name match.
# 	 Encoding 77 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 76 enums.
#
# OTHERCPT6
# 	 Forced categorical based on name match.
# 	 Encoding 41 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 40 enums.
#
# OTHERCPT7
# 	 Forced categorical based on name match.
# 	 Encoding 18 enumerations:
# 	 Found enumerated NaNs...
# ['20900.0' '20926.0' '27606.0' '27625.0' '27687.0' '28120.0' '28208.0'
#  '28232.0' '28285.0' '28300.0' '28304.0' '28306.0' '28308.0' '29515.0'
#  '64450.0' '90471.0' '97605.0']
#
# OTHERCPT8
# 	 Forced categorical based on name match.
# 	 Encoding 9 enumerations:
# 	 Found enumerated NaNs...
# ['27640.0' '27687.0' '27690.0' '27871.0' '28208.0' '28285.0' '28290.0'
#  '28306.0']
#
# OTHERCPT9
# 	 Forced categorical based on name match.
# 	 Encoding 6 enumerations:
# 	 Found enumerated NaNs...
# ['27698.0' '28208.0' '28285.0' '28300.0' '28308.0']
#
# OTHERPROC1
# 	 Column detected categorical.
# 	 Encoding 473 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 472 enums.
#
# OTHERPROC10
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['CAPSUL MTTARPHLNGL JT +-TENORRHAPHY EA JT SPX'
#  'TR/TRNSPL 1 TDN W/MUSC REDIRION/REROUTING DP']
#
# OTHERPROC2
# 	 Column detected categorical.
# 	 Encoding 355 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 354 enums.
#
# OTHERPROC3
# 	 Column detected categorical.
# 	 Encoding 232 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 231 enums.
#
# OTHERPROC4
# 	 Column detected categorical.
# 	 Encoding 132 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 131 enums.
#
# OTHERPROC5
# 	 Column detected categorical.
# 	 Encoding 80 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 79 enums.
#
# OTHERPROC6
# 	 Column detected categorical.
# 	 Encoding 41 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 40 enums.
#
# OTHERPROC7
# 	 Column detected categorical.
# 	 Encoding 18 enumerations:
# 	 Found enumerated NaNs...
# ['APPLICATION SHORT LEG SPLINT CALF FOOT' 'ARTHROTOMY W/SYNOVECTOMY ANKLE'
#  'BONE GRAFT ANY DONOR AREA MINOR/SMALL' 'CORRECTION HAMMERTOE'
#  'GASTROCNEMIUS RECESSION' 'IMADM PRQ ID SUBQ/IM NJXS 1 VACCINE'
#  'INJECTION ANES OTHER PERIPHERAL NERVE/BRANCH'
#  'NEG PRESS WND THER </EQUAL 50 SQ CM'
#  'OSTEOT W/WO LNGTH SHRT/CORRJ 1ST METAR'
#  'OSTEOT W/WO LNGTH SHRT/CORRJ METAR XCP 1ST EA'
#  'OSTEOTOMY CALCANEUS +-INTERNAL FIXATION'
#  'OSTEOTOMY TARSAL BONES OTH/THN CALCANEUS/TALUS'
#  'PRTL EXC B1 TALUS/CALCANEUS'
#  'REPAIR TENDON EXTENSOR FOOT 1/2 EACH TENDON'
#  'TENOTOMY PRQ ACHILLES TENDON SPX GENERAL ANES' 'TISSUE GRAFTS OTHER'
#  'TX OPN TDN FLXR TOE 1 TDN SPX']
#
# OTHERPROC8
# 	 Column detected categorical.
# 	 Encoding 9 enumerations:
# 	 Found enumerated NaNs...
# ['ARTHRODESIS TIBIOFIBULAR JOINT PROXIMAL/DISTAL' 'CORRECTION HAMMERTOE'
#  'CORRJ HALLUX VALGUS W/WO SESMDC SMPL EXOSTECTOMY'
#  'GASTROCNEMIUS RECESSION' 'OSTEOT W/WO LNGTH SHRT/CORRJ 1ST METAR'
#  'PARTIAL EXCISION BONE TIBIA'
#  'REPAIR TENDON EXTENSOR FOOT 1/2 EACH TENDON'
#  'TR/TRNSPL 1 TDN W/MUSC REDIRION/REROUTING SUPFC']
#
# OTHERPROC9
# 	 Column detected categorical.
# 	 Encoding 7 enumerations:
# 	 Found enumerated NaNs...
# ['CORRECTION HAMMERTOE' 'OSTEOT +-LNGTH SHRT/CORRJ METAR XCP 1ST EA'
#  'OSTEOT W/WO LNGTH SHRT/CORRJ METAR XCP 1ST EA'
#  'OSTEOTOMY CALCANEUS +-INTERNAL FIXATION'
#  'REPAIR SECONDARY DISRUPTED LIGAMENT ANKLE COLTRL'
#  'REPAIR TENDON EXTENSOR FOOT 1/2 EACH TENDON']
#
# OTHERWRVU1
# 	 Column detected numeric.
# 	 Number NaN: 14334
#
# OTHERWRVU10
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['10.49' '4.93']
#
# OTHERWRVU2
# 	 Column detected numeric.
# 	 Number NaN: 17729
#
# OTHERWRVU3
# 	 Column detected numeric.
# 	 Number NaN: 18830
#
# OTHERWRVU4
# 	 Column detected numeric.
# 	 Number NaN: 19240
#
# OTHERWRVU5
# 	 Column detected numeric.
# 	 Number NaN: 19408
#
# OTHERWRVU6
# 	 Column detected numeric.
# 	 Number NaN: 19476
#
# OTHERWRVU7
# 	 Column detected numeric.
# 	 Number NaN: 19513
#
# OTHERWRVU8
# 	 Column detected categorical.
# 	 Encoding 9 enumerations:
# 	 Found enumerated NaNs...
# ['12.24' '4.51' '5.62' '5.83' '6.0' '6.41' '9.17' '9.54']
#
# OTHERWRVU9
# 	 Column detected categorical.
# 	 Encoding 6 enumerations:
# 	 Found enumerated NaNs...
# ['4.51' '5.48' '5.62' '9.61' '9.73']
#
# OTHGRAFL
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['Graft/Prosthesis/Flap Failure' 'No Complication']
#
# OTHSESHOCK
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['No Complication' 'Septic Shock']
#
# OTHSYSEP
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['No Complication' 'Sepsis']
#
# OUPNEUMO
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['No Complication' 'Pneumonia']
#
# PACKS
# 	 Column detected numeric.
# 	 Number NaN: 14336
#
# PARA
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# PGY
# 	 Column detected numeric.
# 	 Number NaN: 14515
#
# PNAPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# PODIAG
# 	 Forced categorical based on name match.
# 	 Encoding 499 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 498 enums.
#
# PODIAG10
# 	 Forced categorical based on name match.
# 	 Encoding 125 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 124 enums.
#
# PODIAGTX
# 	 Forced categorical based on name match.
# 	 Encoding 507 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 506 enums.
#
# PODIAGTX10
# 	 Forced categorical based on name match.
# 	 Encoding 125 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 124 enums.
#
# PODIAG_OTHER
# 	 Forced categorical based on name match.
# 	 Encoding 26 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 25 enums.
#
# PODIAG_OTHER10
# 	 Forced categorical based on name match.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['T88.6XXA']
#
# PRALBUM
# 	 Column detected numeric.
# 	 Number NaN: 14636
#
# PRALKPH
# 	 Column detected numeric.
# 	 Number NaN: 14683
#
# PRBILI
# 	 Column detected numeric.
# 	 Number NaN: 14718
#
# PRBUN
# 	 Column detected numeric.
# 	 Number NaN: 8181
#
# PRCREAT
# 	 Column detected numeric.
# 	 Number NaN: 7793
#
# PREGNANCY
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# PRHCT
# 	 Column detected numeric.
# 	 Number NaN: 6902
#
# PRINR
# 	 Column detected numeric.
# 	 Number NaN: 13314
#
# PRNCPTX
# 	 Forced categorical based on name match.
# 	 Encoding 104 enumerations:
# 	 Skipping due to 104 enums.
#
# PROPER30
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# PRPLATE
# 	 Column detected numeric.
# 	 Number NaN: 7154
#
# PRPT
# 	 Column detected numeric.
# 	 Number NaN: 17883
#
# PRPTT
# 	 Column detected numeric.
# 	 Number NaN: 14983
#
# PRSEPIS
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# ['None' 'SIRS' 'Sepsis' 'Septic Shock']
#
# PRSGOT
# 	 Column detected numeric.
# 	 Number NaN: 14568
#
# PRSODM
# 	 Column detected numeric.
# 	 Number NaN: 7798
#
# PRVPCI
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# PRVPCS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# PRWBC
# 	 Column detected numeric.
# 	 Number NaN: 7126
#
# PULEMBOL
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['No Complication' 'Pulmonary Embolism']
#
# QUAD
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# RACE_NEW
# 	 Column detected categorical.
# 	 Encoding 8 enumerations:
# 	 Found enumerated NaNs...
# ['American Indian or Alaska Native' 'Asian' 'Black or African American'
#  'Native Hawaiian or Pacific Islander' 'Unknown' 'Unknown/Not Reported'
#  'White']
#
# RADIO
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# RBC
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# ['0.0' '1.0' '2.0' '4.0']
#
# READMISSION
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# READMISSION1
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# READMISSION2
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# READMISSION3
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# []
#
# READMISSION4
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# []
#
# READMISSION5
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# []
#
# READMPODAYS1
# 	 Column detected numeric.
# 	 Number NaN: 19186
#
# READMPODAYS2
# 	 Column detected numeric.
# 	 Number NaN: 19521
#
# READMPODAYS3
# 	 Skipping because there is only 1 value.
#
# READMPODAYS4
# 	 Skipping because there is only 1 value.
#
# READMPODAYS5
# 	 Skipping because there is only 1 value.
#
# READMRELATED1
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# READMRELATED2
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# READMRELATED3
# 	 Skipping because there is only 1 value.
#
# READMRELATED4
# 	 Skipping because there is only 1 value.
#
# READMRELATED5
# 	 Skipping because there is only 1 value.
#
# READMRELICD101
# 	 Forced categorical based on name match.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['S89.399A']
#
# READMRELICD102
# 	 Skipping because there is only 1 value.
#
# READMRELICD103
# 	 Skipping because there is only 1 value.
#
# READMRELICD104
# 	 Skipping because there is only 1 value.
#
# READMRELICD105
# 	 Skipping because there is only 1 value.
#
# READMRELICD91
# 	 Forced categorical based on name match.
# 	 Encoding 44 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 43 enums.
#
# READMRELICD92
# 	 Forced categorical based on name match.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['560.1' '780.6']
#
# READMRELICD93
# 	 Skipping because there is only 1 value.
#
# READMRELICD94
# 	 Skipping because there is only 1 value.
#
# READMRELICD95
# 	 Skipping because there is only 1 value.
#
# READMSUSPREASON1
# 	 Column detected categorical.
# 	 Encoding 18 enumerations:
# 	 Found enumerated NaNs...
# ['Acute Renal Failure' 'DVT Requiring Therapy' 'Deep Incisional SSI'
#  'Graft/Prosthesis/Flap Failure' 'Myocardial Infarction' 'Organ/Space SSI'
#  'Other (list ICD 10 code)' 'Other (list ICD 9 code)' 'Pneumonia'
#  'Pulmonary Embolism' 'Sepsis' 'Septic Shock' 'Superficial Incisional SSI'
#  'Unplanned Intubation' 'Urinary Tract Infection'
#  'Vein Thrombosis Requiring Therapy' 'Wound Disruption']
#
# READMSUSPREASON2
# 	 Column detected categorical.
# 	 Encoding 6 enumerations:
# 	 Found enumerated NaNs...
# ['DVT Requiring Therapy' 'Deep Incisional SSI' 'Other (list ICD 9 code)'
#  'Superficial Incisional SSI' 'Wound Disruption']
#
# READMSUSPREASON3
# 	 Skipping because there is only 1 value.
#
# READMSUSPREASON4
# 	 Skipping because there is only 1 value.
#
# READMSUSPREASON5
# 	 Skipping because there is only 1 value.
#
# READMUNRELICD101
# 	 Forced categorical based on name match.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# ['C78.5' 'K29.0' 'R62.7']
#
# READMUNRELICD102
# 	 Skipping because there is only 1 value.
#
# READMUNRELICD103
# 	 Skipping because there is only 1 value.
#
# READMUNRELICD104
# 	 Skipping because there is only 1 value.
#
# READMUNRELICD105
# 	 Skipping because there is only 1 value.
#
# READMUNRELICD91
# 	 Forced categorical based on name match.
# 	 Encoding 52 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 51 enums.
#
# READMUNRELICD92
# 	 Forced categorical based on name match.
# 	 Encoding 6 enumerations:
# 	 Found enumerated NaNs...
# ['291.81' '401.9' '486.0' '586.0' '8.45']
#
# READMUNRELICD93
# 	 Skipping because there is only 1 value.
#
# READMUNRELICD94
# 	 Skipping because there is only 1 value.
#
# READMUNRELICD95
# 	 Skipping because there is only 1 value.
#
# READMUNRELSUSP1
# 	 Column detected categorical.
# 	 Encoding 9 enumerations:
# 	 Found enumerated NaNs...
# ['Acute Renal Failure' 'Deep Incisional SSI' 'Myocardial Infarction'
#  'Organ/Space SSI' 'Other (list ICD10 code)' 'Other (list ICD9 code)'
#  'Pneumonia' 'Urinary Tract Infection']
#
# READMUNRELSUSP2
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['Other (list ICD9 code)']
#
# READMUNRELSUSP3
# 	 Skipping because there is only 1 value.
#
# READMUNRELSUSP4
# 	 Skipping because there is only 1 value.
#
# READMUNRELSUSP5
# 	 Skipping because there is only 1 value.
#
# REINTUB
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['No Complication' 'Unplanned Intubation']
#
# RENAFAIL
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# RENAINSF
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['No Complication' 'Progressive Renal Insufficiency']
#
# REOPERATION
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# REOPERATION1
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# REOPERATION2
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# REOPERATION3
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# REOPOR1ICD101
# 	 Forced categorical based on name match.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['T81.4XXA' 'Z86.31']
#
# REOPOR2CPT1
# 	 Forced categorical based on name match.
# 	 Encoding 18 enumerations:
# 	 Found enumerated NaNs...
# ['10180.0' '11012.0' '11042.0' '11043.0' '11044.0' '11045.0' '11046.0'
#  '12036.0' '13160.0' '14021.0' '20680.0' '27610.0' '27792.0' '27827.0'
#  '27880.0' '31610.0' '97605.0']
#
# REOPOR2ICD101
# 	 Skipping because there is only 1 value.
#
# REOPOR2ICD91
# 	 Forced categorical based on name match.
# 	 Encoding 12 enumerations:
# 	 Found enumerated NaNs...
# ['41.11' '733.8' '824.5' '958.92' '996.49' '996.67' '997.6' '998.3'
#  '998.32' '998.5' '998.59']
#
# REOPORCPT1
# 	 Forced categorical based on name match.
# 	 Encoding 93 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 92 enums.
#
# REOPORICD91
# 	 Forced categorical based on name match.
# 	 Encoding 65 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 64 enums.
#
# RESTPAIN
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# RETOR2PODAYS
# 	 Column detected numeric.
# 	 Number NaN: 19506
#
# RETOR2RELATED
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# ['No' 'Unknown' 'Yes']
#
# RETORPODAYS
# 	 Column detected numeric.
# 	 Number NaN: 19329
#
# RETORRELATED
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# ['No' 'Unknown' 'Yes']
#
# RETURNOR
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# ['Yes']
#
# SDISDT
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# ['2008.0' '2009.0' '2010.0']
#
# SEPSHOCKPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# SEPSISPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# SEX
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# ['female' 'male']
#
# SMOKE
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# ['Yes']
#
# SSSIPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# STEROID
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# ['Yes']
#
# STILLINHOSP
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# STOODAY
# 	 Column detected numeric.
# 	 Number NaN: 17603
#
# SUPINFEC
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['No Complication' 'Superficial Incisional SSI']
#
# SURGANE
# 	 Column detected numeric.
# 	 Number NaN: 13114
#
# SURGSPEC
# 	 Skipping because there is only 1 value.
#
# TOTHLOS
# 	 Column detected numeric.
# 	 Number NaN: 11
#
# TOTSLOS
# 	 Column detected numeric.
# 	 Number NaN: 17603
#
# TRANSFUS
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# ['Yes']
#
# TRANST
# 	 Column detected categorical.
# 	 Encoding 11 enumerations:
# ['Acute Care Hospital' 'Admitted directly from home'
#  'Chronic Care Facility' 'From acute care hospital inpatient'
#  'Not transferred (admitted from home)'
#  'Nursing home - Chronic care - Intermediate care' 'Other'
#  'Outside emergency department' 'Transfer from other' 'Unknown'
#  'VA Acute Care Hospital']
#
# TUMORCNS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# TYPEINTOC
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# ['Unplanned Intubation']
#
# UNPLANNEDREADMISSION1
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# UNPLANNEDREADMISSION2
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# UNPLANNEDREADMISSION3
# 	 Skipping because there is only 1 value.
#
# UNPLANNEDREADMISSION4
# 	 Skipping because there is only 1 value.
#
# UNPLANNEDREADMISSION5
# 	 Skipping because there is only 1 value.
#
# UNPLANREADMISSION
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# URNINFEC
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['No Complication' 'Urinary Tract Infection']
#
# UTIPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# VENTILAT
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# ['Yes']
#
# VENTPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# ['Yes']
#
# WEIGHT
# 	 Column detected numeric.
# 	 Number NaN: 584
#
# WNDCLAS
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# ['1-Clean' '2-Clean/Contaminated' '3-Contaminated' '4-Dirty/Infected']
#
# WNDINF
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# ['Yes']
#
# WNDINFD
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# ['Deep Incisional SSI' 'No Complication']
#
# WORKRVU
# 	 Column detected numeric.
# 	 Number NaN: 0
#
# WOUND_CLOSURE
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# ['All layers of incision (deep and superficial) fully closed'
#  'No layers of incision are surgically closed'
#  'Only deep layers closed; superficial left open']
#
# WTLOSS
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# ['Yes']
#
# YRDEATH
# 	 Column detected categorical.
# 	 Encoding 9 enumerations:
# 	 Found enumerated NaNs...
# ['2008.0' '2009.0' '2010.0' '2011.0' '2012.0' '2013.0' '2014.0' '2015.0']

# %% [markdown]
# Ok, let's save this cleaned up data to disk. Note that there are still missing values for numeric variables.

# %%
cdf.to_pickle(mungedFileName)

# %%
# cdf['intercept'] = 1.0
# X = cdf.copy()
# X.drop('READMISSION1-Yes',1)

# imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
# imp.fit(X)
# X = imp.transform(X) 
# X.shape

# logistic = linear_model.LogisticRegression(C=1e5, verbose=True)
# logistic.fit(X, cdf['READMISSION1-Yes'])
