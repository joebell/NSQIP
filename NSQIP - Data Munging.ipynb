# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing as pp
import warnings 
warnings.filterwarnings("ignore") # Ignore annoying warnings

dataDir = './Data/'
compiledFileName = dataDir + 'compiledData.pkl'
mungedFileName = dataDir + 'mungedData.pkl'

df = pd.read_pickle(compiledFileName)

# %% [markdown]
# The strategy should be:
# - Numeric items should be checked for numeracy, and kept as numbers. If there are non-numeric things we need to prompt for appropriate replacement. If there are only a few numbers, we actually probably want them as categories.
# - Items as text should be encoded as one-hot binary variables, and a LabelEncoder should be created for them.

# %%
# Utility function to see if a column has only real numeric values.
# NaN's are ok.
def numeracyCheck( column):
    nonNumerics = column[~column.apply(np.isreal)]
    if len(nonNumerics) > 0:
        print('\t Non-numeric values found at %d spots: ' % len(nonNumerics))
        print(pd.unique(nonNumerics))
        return False
    else:
        return True

# Utility function for encoding enumerated text as a collection of 
# one-hot binary vectors. This enumerates NaNs, so they don't show as
# missing data. We will reassign them as missing data.
def binarizeColumn( column):

    le = pp.LabelBinarizer(neg_label=0, pos_label=1, sparse_output=False)
    # Label binarizer will warn on NaNs
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
    y = le.fit_transform(column.map(str))
    # Fix bad behavior from LabelBinarizer
    if (y.shape[1] == 1) and (len(le.classes_)==2):
        y = np.concatenate((1-y,y),axis=1)
    print('\t Encoding %d enumerations: ' % len(le.classes_))
    
    # If there are any classes matching 'nan'
    if ('nan' in le.classes_):
        print('\t Found enumerated NaNs...')
        nanCols = [index for index, aClass in enumerate(le.classes_) if aClass == 'nan' ]
        y = np.delete(y, nanCols, axis=1).astype(float)   # Delete the column in y
        le.classes_ = np.delete(le.classes_, nanCols)     # Delete the nan class label
        y[np.nonzero(pd.isnull(column)),:] = np.nan       # Set the nan rows to nan

    # Now check to see if our only remaining choices are 'Yes' and 'No'. If so, we only have to return 'Yes'    
    matchList = ['Yes', 'No']
    if all([any([leClass == target for target in matchList]) for leClass in le.classes_]):
        print('\t Binary response; returning only Yes')
        noCols = [index for index, aClass in enumerate(le.classes_) if aClass == 'No' ]
        y = np.delete(y, noCols, axis=1).astype(float)   # Delete the column in y
        le.classes_ = np.delete(le.classes_, noCols)   # Delete the No class label

    return y, le

# Force a column to be categorical
def forceCat( colName):
    matchList = ['CPT', 'PODIAG', 'ICD']
    force = any(ext in colName for ext in matchList)
    return force

# Force a column to be continuous
def forceCont( colName):
    matchList = ['RBC']
    force = any(ext in colName for ext in matchList)
    return force

# Utility function to determine whether a column should be numeric or categorical.
def numOrCat( column, colName):
    
    if forceCat( colName):
        print('\t Forced categorical based on name match.')
        return False
    elif forceCont(colName):
        print('\t Forced continuous based on name match.')
        return True

    numericThresh = 0.5  # Assume categorical if < numericThresh are numeric
    uniqueThresh  = 10   # Assume categorical if < uniqueThresh unique numbers

    nonNumerics = column[~column.apply(np.isreal) & ~column.apply(pd.isnull)]
    numerics    = column[column.apply(np.isreal) & ~column.apply(pd.isnull)]
    Nuniques = len(column.unique())

    if ((len(nonNumerics)/(len(numerics)+1)) > numericThresh) or (Nuniques < uniqueThresh):
        print('\t Column detected categorical.')
        return False
    else:
        print('\t Column detected numeric.')
        return True

# %% [markdown]
# Now we loop through all the columns in our existing DataFrame and make a clean version that has our appropriately cleaned and coded variables. Some of these variables are text fields (like procedure descriptions) that have many options. We'd need to do some feature extraction here to make this useful; for now we'll just leave these features out.
#
# This code should idenitfy any problems in the source DataFrame. I'll try to proactively address those by cleaning the data and giving a list of columns that should be forced categorical.

# %%
# Replace any '90+' age annotations with age 90.
df.loc[df['AGE'] == '90+','AGE'] = 90.0

# %%
# Make a clean DataFrame
cdf = pd.DataFrame()

for colName in df.columns:
    print('  ')
    print(colName)
    aColumn = df[colName]
    
    if len(aColumn.unique()) < 2:
        print('\t Skipping because there is only 1 value.')
        continue
    
    # If it looks numeric and isn't in our list to force categorical...
    if numOrCat(aColumn, colName):
        # If it's numeric
        if numeracyCheck(aColumn):
            # The column is a clean numeric column (but could have NaNs)
            nNaNs = sum(aColumn.isnull())
            print('\t Number NaN: %d' % nNaNs)
            
            # Add it to the clean DataFrame
            cdf[colName] = aColumn         
        else:
            # We need to clean it up
            print('*** Clean This Up ***')
    else:
        # If it needs to be categorical
        y, le = binarizeColumn(aColumn)
        nEnums = y.shape[1] + 1
        if (nEnums <= 20):
            for binColN in np.arange(y.shape[1]):
                print('\t Fract: %.3f \'%s\'' % (np.nanmean(y[:,binColN]),le.classes_[binColN]))
                subColName = colName + '-' + le.classes_[binColN]
                cdf[subColName] = y[:,binColN]
        else:
            
            print('\t Skipping due to %d enums.' % nEnums)
# Out:
#
# ADMQTR
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Fract: 0.261 '1'
# 	 Fract: 0.227 '2'
# 	 Fract: 0.248 '3'
# 	 Fract: 0.264 '4'
#
# ADMSYR
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.001 '2007.0'
# 	 Fract: 0.381 '2008.0'
# 	 Fract: 0.619 '2009.0'
#
# ADMYR
# 	 Column detected categorical.
# 	 Encoding 8 enumerations:
# 	 Fract: 0.000 '2007'
# 	 Fract: 0.038 '2008'
# 	 Fract: 0.061 '2009'
# 	 Fract: 0.090 '2010'
# 	 Fract: 0.116 '2011'
# 	 Fract: 0.165 '2012'
# 	 Fract: 0.227 '2013'
# 	 Fract: 0.303 '2014'
#
# AGE
# 	 Column detected numeric.
# 	 Number NaN: 0
#
# AIRTRA
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.001 'Lip laceration or hematoma'
# 	 Fract: 0.998 'None'
# 	 Fract: 0.001 'Tooth chipped, loosened or lost'
#
# ANESTHES
# 	 Column detected categorical.
# 	 Encoding 10 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.001 'Epidural'
# 	 Fract: 0.862 'General'
# 	 Fract: 0.001 'Local'
# 	 Fract: 0.021 'MAC/IV Sedation'
# 	 Fract: 0.001 'Monitored Anesthesia Care'
# 	 Fract: 0.000 'None'
# 	 Fract: 0.001 'Other'
# 	 Fract: 0.017 'Regional'
# 	 Fract: 0.095 'Spinal'
#
# ANESTHES_OTHER
# 	 Column detected categorical.
# 	 Encoding 18 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.007 'Epidural'
# 	 Fract: 0.001 'Epidural,Regional'
# 	 Fract: 0.015 'General'
# 	 Fract: 0.196 'Local'
# 	 Fract: 0.004 'Local,Monitored Anesthesia Care/IV Sedation'
# 	 Fract: 0.001 'Local,Other'
# 	 Fract: 0.079 'Monitored Anesthesia Care/IV Sedation'
# 	 Fract: 0.015 'Other'
# 	 Fract: 0.566 'Regional'
# 	 Fract: 0.020 'Regional,Local'
# 	 Fract: 0.017 'Regional,Monitored Anesthesia Care/IV Sedation'
# 	 Fract: 0.001 'Regional,Other'
# 	 Fract: 0.068 'Spinal'
# 	 Fract: 0.001 'Spinal,Epidural'
# 	 Fract: 0.001 'Spinal,Local'
# 	 Fract: 0.001 'Spinal,Monitored Anesthesia Care/IV Sedation'
# 	 Fract: 0.007 'Spinal,Regional'
#
# ANESURG
# 	 Column detected numeric.
# 	 Number NaN: 13062
#
# ANETIME
# 	 Column detected numeric.
# 	 Number NaN: 13052
#
# ASACLAS
# 	 Column detected categorical.
# 	 Encoding 7 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.223 '1-No Disturb'
# 	 Fract: 0.512 '2-Mild Disturb'
# 	 Fract: 0.241 '3-Severe Disturb'
# 	 Fract: 0.023 '4-Life Threat'
# 	 Fract: 0.000 '5-Moribund'
# 	 Fract: 0.001 'None assigned'
#
# ASCITES
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# 	 Fract: 0.000 'Yes'
#
# ATTEND
# 	 Column detected categorical.
# 	 Encoding 7 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.256 'Attending & Resident in OR'
# 	 Fract: 0.640 'Attending Alone'
# 	 Fract: 0.002 'Attending Not Present, but Available'
# 	 Fract: 0.098 'Attending in OR'
# 	 Fract: 0.001 'Attending in OR Suite'
# 	 Fract: 0.002 'Not entered'
#
# BLEEDDIS
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# 	 Fract: 0.031 'Yes'
#
# CASEID
# 	 Column detected numeric.
# 	 Number NaN: 0
#
# CDARREST
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.001 'Cardiac Arrest Requiring CPR'
# 	 Fract: 0.999 'No Complication'
#
# CDMI
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.001 'Myocardial Infarction'
# 	 Fract: 0.999 'No Complication'
#
# CHEMO
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.002 'Yes'
#
# CNSCOMA
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.000 'Coma greater than 24 Hours'
# 	 Fract: 1.000 'No Complication'
#
# CNSCVA
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 1.000 'No Complication'
# 	 Fract: 0.000 'Stroke/CVA'
#
# COMA
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.000 'Yes'
#
# CONCPT1
# 	 Forced categorical based on name match.
# 	 Encoding 43 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 43 enums.
#
# CONCPT10
# 	 Forced categorical based on name match.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 '11045.0'
#
# CONCPT2
# 	 Forced categorical based on name match.
# 	 Encoding 13 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.083 '11010.0'
# 	 Fract: 0.083 '12002.0'
# 	 Fract: 0.083 '13120.0'
# 	 Fract: 0.083 '15003.0'
# 	 Fract: 0.083 '15101.0'
# 	 Fract: 0.083 '15120.0'
# 	 Fract: 0.083 '20694.0'
# 	 Fract: 0.083 '27691.0'
# 	 Fract: 0.083 '27792.0'
# 	 Fract: 0.083 '52000.0'
# 	 Fract: 0.083 '64445.0'
# 	 Fract: 0.083 '97605.0'
#
# CONCPT3
# 	 Forced categorical based on name match.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.250 '11042.0'
# 	 Fract: 0.250 '11044.0'
# 	 Fract: 0.250 '15100.0'
# 	 Fract: 0.250 '28306.0'
#
# CONCPT4
# 	 Forced categorical based on name match.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.333 '11045.0'
# 	 Fract: 0.333 '15101.0'
# 	 Fract: 0.333 '27659.0'
#
# CONCPT5
# 	 Forced categorical based on name match.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.500 '11045.0'
# 	 Fract: 0.500 '27687.0'
#
# CONCPT6
# 	 Forced categorical based on name match.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 '11045.0'
#
# CONCPT7
# 	 Forced categorical based on name match.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 '11045.0'
#
# CONCPT8
# 	 Forced categorical based on name match.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 '11045.0'
#
# CONCPT9
# 	 Forced categorical based on name match.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 '11045.0'
#
# CONCURR1
# 	 Column detected categorical.
# 	 Encoding 43 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 43 enums.
#
# CONCURR10
# 	 Column detected categorical.
# 	 Encoding 6 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.143 'FLUOR PHYS TM > 1 HR ASSISTING NON-RAD PHYS'
# 	 Fract: 0.143 'MUSC MYOCUTANEOUS/FASCIOCUTANEOUS FLAP LXTR'
# 	 Fract: 0.143 'MUSCLE TRANSFER SHOULDER/UPPER ARM SINGLE'
# 	 Fract: 0.286 'REMOVAL EXTERNAL FIXATION SYSTEM UNDER ANES'
# 	 Fract: 0.286 'SPLIT AGRFT T/A/L 1ST 100 CM/</1% BDY INFT/CHLD'
#
# CONCURR2
# 	 Column detected categorical.
# 	 Encoding 13 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.083 'CYSTOURETHROSCOPY'
# 	 Fract: 0.083 'DBRDMT W/RMVL FM FX&/DISLC SKIN&SUBQ TISSUS'
# 	 Fract: 0.083 'INJECTION ANESTHETIC AGENT SCIATIC NRV SINGLE'
# 	 Fract: 0.083 'NEGATIVE PRESSURE WOUND THERAPY </= 50 SQ CM'
# 	 Fract: 0.083 'OPEN TX DISTAL FIBULAR FRACTURE LAT MALLEOLUS'
# 	 Fract: 0.083 'PREP SITE TRUNK/ARM/LEG ADDL 100 SQ CM/1PCT'
# 	 Fract: 0.083 'REMOVAL EXTERNAL FIXATION SYSTEM UNDER ANES'
# 	 Fract: 0.083 'REPAIR COMPLEX SCALP/ARM/LEG 1.1-2.5 CM'
# 	 Fract: 0.083 'SMPL REPAIR SCALP/NECK/AX/GENIT/TRUNK 2.6-7.5CM'
# 	 Fract: 0.083 'SPLIT AGRFT F/S/N/H/F/G/M/D GT 1ST 100 CM<1 %'
# 	 Fract: 0.083 'SPLIT AGRFT T/A/L EA 100 CM/EA 1% BDY INFT/CHLD'
# 	 Fract: 0.083 'TR/TRNSPL 1 TDN W/MUSC REDIRION/REROUTING DP'
#
# CONCURR3
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.250 'DEBRIDEMENT BONE MUSCLE &/FASCIA 20 SQ CM/<'
# 	 Fract: 0.250 'DEBRIDEMENT SUBCUTANEOUS TISSUE 20 SQ CM/<'
# 	 Fract: 0.250 'OSTEOT W/WO LNGTH SHRT/CORRJ 1ST METAR'
# 	 Fract: 0.250 'SPLIT AGRFT T/A/L 1ST 100 CM/&/1% BDY INFT/CHLD'
#
# CONCURR4
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.333 'DBRDMT SUBCUTANEOUS TISSUE EA ADDL 20 SQ CM'
# 	 Fract: 0.333 'RPR FLEXOR TENDON LEG SECONDARY W/O GRAFT EACH'
# 	 Fract: 0.333 'SPLIT AGRFT T/A/L EA 100 CM/EA 1% BDY INFT/CHLD'
#
# CONCURR5
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.500 'DBRDMT SUBCUTANEOUS TISSUE EA ADDL 20 SQ CM'
# 	 Fract: 0.500 'GASTROCNEMIUS RECESSION'
#
# CONCURR6
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 'DBRDMT SUBCUTANEOUS TISSUE EA ADDL 20 SQ CM'
#
# CONCURR7
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 'DBRDMT SUBCUTANEOUS TISSUE EA ADDL 20 SQ CM'
#
# CONCURR8
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 'DBRDMT SUBCUTANEOUS TISSUE EA ADDL 20 SQ CM'
#
# CONCURR9
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 'DBRDMT SUBCUTANEOUS TISSUE EA ADDL 20 SQ CM'
#
# CONWRVU1
# 	 Column detected numeric.
# 	 Number NaN: 19485
#
# CONWRVU10
# 	 Skipping because there is only 1 value.
#
# CONWRVU2
# 	 Column detected numeric.
# 	 Number NaN: 19521
#
# CONWRVU3
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.250 '0.8'
# 	 Fract: 0.250 '4.1'
# 	 Fract: 0.250 '6.0'
# 	 Fract: 0.250 '9.9'
#
# CONWRVU4
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.500 '1.72'
# 	 Fract: 0.500 '7.1'
#
# CONWRVU5
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 '6.41'
#
# CONWRVU6
# 	 Skipping because there is only 1 value.
#
# CONWRVU7
# 	 Skipping because there is only 1 value.
#
# CONWRVU8
# 	 Skipping because there is only 1 value.
#
# CONWRVU9
# 	 Skipping because there is only 1 value.
#
# CPNEUMON
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.001 'Yes'
#
# CPT
# 	 Forced categorical based on name match.
# 	 Encoding 62 enumerations:
# 	 Skipping due to 63 enums.
#
# CVA
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.013 'Yes'
#
# CVANO
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.010 'Yes'
#
# DCDARREST
# 	 Column detected numeric.
# 	 Number NaN: 19516
#
# DCDMI
# 	 Column detected numeric.
# 	 Number NaN: 19515
#
# DCNSCOMA
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 '4.0'
#
# DCNSCVA
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.250 '0.0'
# 	 Fract: 0.250 '10.0'
# 	 Fract: 0.250 '3.0'
# 	 Fract: 0.250 '4.0'
#
# DDEHIS
# 	 Column detected numeric.
# 	 Number NaN: 19461
#
# DEHIS
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.996 'No Complication'
# 	 Fract: 0.004 'Wound Disruption'
#
# DFAILWEAN
# 	 Column detected numeric.
# 	 Number NaN: 19501
#
# DIABETES
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.056 'INSULIN'
# 	 Fract: 0.879 'NO'
# 	 Fract: 0.058 'NON-INSULIN'
# 	 Fract: 0.006 'ORAL'
#
# DIALYSIS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.007 'Yes'
#
# DISCANCR
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# 	 Fract: 0.002 'Yes'
#
# DISCHDEST
# 	 Column detected categorical.
# 	 Encoding 9 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.001 'Expired'
# 	 Fract: 0.009 'Facility Which was Home'
# 	 Fract: 0.887 'Home'
# 	 Fract: 0.027 'Rehab'
# 	 Fract: 0.004 'Separate Acute Care'
# 	 Fract: 0.069 'Skilled Care, Not Home'
# 	 Fract: 0.001 'Unknown'
# 	 Fract: 0.003 'Unskilled Facility Not Home'
#
# DNEURODEF
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.500 '0.0'
# 	 Fract: 0.500 '13.0'
#
# DNR
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.006 'Yes'
#
# DOPERTOD
# 	 Column detected numeric.
# 	 Number NaN: 0
#
# DOPRENAFL
# 	 Column detected numeric.
# 	 Number NaN: 19522
#
# DOPTODIS
# 	 Column detected numeric.
# 	 Number NaN: 5
#
# DORGSPCSSI
# 	 Column detected numeric.
# 	 Number NaN: 19494
#
# DOTHBLEED
# 	 Column detected categorical.
# 	 Encoding 6 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.219 '0.0'
# 	 Fract: 0.348 '1.0'
# 	 Fract: 0.335 '2.0'
# 	 Fract: 0.090 '3.0'
# 	 Fract: 0.006 '6.0'
#
# DOTHDVT
# 	 Column detected numeric.
# 	 Number NaN: 19457
#
# DOTHGRAFL
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.333 '14.0'
# 	 Fract: 0.667 '27.0'
#
# DOTHSESHOCK
# 	 Column detected numeric.
# 	 Number NaN: 19514
#
# DOTHSYSEP
# 	 Column detected numeric.
# 	 Number NaN: 19461
#
# DOUPNEUMO
# 	 Column detected numeric.
# 	 Number NaN: 19462
#
# DPATRM
# 	 Column detected numeric.
# 	 Number NaN: 13003
#
# DPRALBUM
# 	 Column detected numeric.
# 	 Number NaN: 14622
#
# DPRALKPH
# 	 Column detected numeric.
# 	 Number NaN: 14688
#
# DPRBILI
# 	 Column detected numeric.
# 	 Number NaN: 14718
#
# DPRBUN
# 	 Column detected numeric.
# 	 Number NaN: 8201
#
# DPRCREAT
# 	 Column detected numeric.
# 	 Number NaN: 7733
#
# DPRHCT
# 	 Column detected numeric.
# 	 Number NaN: 6813
#
# DPRINR
# 	 Column detected numeric.
# 	 Number NaN: 13323
#
# DPRNA
# 	 Column detected numeric.
# 	 Number NaN: 7813
#
# DPRPLATE
# 	 Column detected numeric.
# 	 Number NaN: 7174
#
# DPRPT
# 	 Column detected numeric.
# 	 Number NaN: 17887
#
# DPRPTT
# 	 Column detected numeric.
# 	 Number NaN: 14987
#
# DPRSGOT
# 	 Column detected numeric.
# 	 Number NaN: 14572
#
# DPRWBC
# 	 Column detected numeric.
# 	 Number NaN: 7140
#
# DPULEMBOL
# 	 Column detected numeric.
# 	 Number NaN: 19480
#
# DREINTUB
# 	 Column detected numeric.
# 	 Number NaN: 19493
#
# DRENAINSF
# 	 Column detected numeric.
# 	 Number NaN: 19520
#
# DSDTOHD
# 	 Column detected categorical.
# 	 Encoding 6 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.998 '0.0'
# 	 Fract: 0.001 '1.0'
# 	 Fract: 0.001 '15.0'
# 	 Fract: 0.001 '61.0'
# 	 Fract: 0.001 '7.0'
#
# DSSIPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.002 'Yes'
#
# DSUPINFEC
# 	 Column detected numeric.
# 	 Number NaN: 19338
#
# DURNINFEC
# 	 Column detected numeric.
# 	 Number NaN: 19405
#
# DWNDINFD
# 	 Column detected numeric.
# 	 Number NaN: 19454
#
# DYSPNEA
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.003 'AT REST'
# 	 Fract: 0.029 'MODERATE EXERTION'
# 	 Fract: 0.969 'No'
#
# ELECTSURG
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.343 'No'
# 	 Fract: 0.001 'Unknown'
# 	 Fract: 0.656 'Yes'
#
# EMERGNCY
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# 	 Fract: 0.139 'Yes'
#
# ESOVAR
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.000 'Yes'
#
# ETHNICITY_HISPANIC
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.782 'No'
# 	 Fract: 0.138 'Unknown'
# 	 Fract: 0.080 'Yes'
#
# ETOH
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.048 'Yes'
#
# FAILWEAN
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.998 'No Complication'
# 	 Fract: 0.002 'On Ventilator greater than 48 Hours'
#
# FNSTATUS1
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.964 'Independent'
# 	 Fract: 0.032 'Partially Dependent'
# 	 Fract: 0.004 'Totally Dependent'
#
# FNSTATUS2
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.947 'Independent'
# 	 Fract: 0.041 'Partially Dependent'
# 	 Fract: 0.003 'Totally Dependent'
# 	 Fract: 0.009 'Unknown'
#
# HDISDT
# 	 Column detected categorical.
# 	 Encoding 9 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.037 '2008.0'
# 	 Fract: 0.061 '2009.0'
# 	 Fract: 0.090 '2010.0'
# 	 Fract: 0.115 '2011.0'
# 	 Fract: 0.165 '2012.0'
# 	 Fract: 0.225 '2013.0'
# 	 Fract: 0.305 '2014.0'
# 	 Fract: 0.001 '2015.0'
#
# HEIGHT
# 	 Column detected numeric.
# 	 Number NaN: 1095
#
# HEMI
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.007 'Yes'
#
# HTOODAY
# 	 Column detected numeric.
# 	 Number NaN: 2
#
# HXANGINA
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.003 'Yes'
#
# HXCHF
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# 	 Fract: 0.004 'Yes'
#
# HXCOPD
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# 	 Fract: 0.029 'Yes'
#
# HXMI
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.003 'Yes'
#
# HXPVD
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.016 'Yes'
#
# HXTIA
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.013 'Yes'
#
# HYPERMED
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# 	 Fract: 0.324 'Yes'
#
# IMPSENS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.003 'Yes'
#
# INOUT
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.445 'Inpatient'
# 	 Fract: 0.555 'Outpatient'
#
# MALLAMP
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.366 '1.0'
# 	 Fract: 0.518 '2.0'
# 	 Fract: 0.104 '3.0'
# 	 Fract: 0.012 '4.0'
#
# MORBPROB
# 	 Column detected numeric.
# 	 Number NaN: 5950
#
# MORTPROB
# 	 Column detected numeric.
# 	 Number NaN: 5950
#
# NCDARREST
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Fract: 0.999 '0'
# 	 Fract: 0.001 '1'
# 	 Fract: 0.000 '2'
#
# NCDMI
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.999 '0'
# 	 Fract: 0.001 '1'
#
# NCNSCOMA
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 '0.0'
# 	 Fract: 0.000 '1.0'
#
# NCNSCVA
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 1.000 '0'
# 	 Fract: 0.000 '1'
#
# NDEHIS
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.996 '0'
# 	 Fract: 0.004 '1'
#
# NEURODEF
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 'No Complication'
# 	 Fract: 0.000 'Peripheral Nerve Injury'
#
# NFAILWEAN
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.998 '0'
# 	 Fract: 0.002 '1'
#
# NNEURODEF
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 '0.0'
# 	 Fract: 0.000 '1.0'
#
# NOPRENAFL
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.999 '0'
# 	 Fract: 0.001 '1'
#
# NORGSPCSSI
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.998 '0'
# 	 Fract: 0.002 '1'
#
# NOTHBLEED
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.992 '0'
# 	 Fract: 0.008 '1'
#
# NOTHDVT
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.996 '0'
# 	 Fract: 0.004 '1'
#
# NOTHGRAFL
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 '0.0'
# 	 Fract: 0.000 '1.0'
#
# NOTHSESHOCK
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.999 '0'
# 	 Fract: 0.001 '1'
#
# NOTHSYSEP
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.996 '0'
# 	 Fract: 0.004 '1'
#
# NOUPNEUMO
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.996 '0'
# 	 Fract: 0.004 '1'
#
# NPULEMBOL
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.997 '0'
# 	 Fract: 0.003 '1'
#
# NREINTUB
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Fract: 0.998 '0'
# 	 Fract: 0.002 '1'
# 	 Fract: 0.000 '2'
#
# NRENAINSF
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.999 '0'
# 	 Fract: 0.001 '1'
#
# NSUPINFEC
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.990 '0'
# 	 Fract: 0.010 '1'
#
# NURNINFEC
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Fract: 0.993 '0'
# 	 Fract: 0.007 '1'
# 	 Fract: 0.000 '2'
#
# NWNDINFD
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.996 '0'
# 	 Fract: 0.004 '1'
#
# OPERYR
# 	 Column detected categorical.
# 	 Encoding 7 enumerations:
# 	 Fract: 0.037 '2008'
# 	 Fract: 0.061 '2009'
# 	 Fract: 0.090 '2010'
# 	 Fract: 0.116 '2011'
# 	 Fract: 0.165 '2012'
# 	 Fract: 0.226 '2013'
# 	 Fract: 0.305 '2014'
#
# OPNOTE
# 	 Skipping because there is only 1 value.
#
# OPRENAFL
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.001 'Acute Renal Failure'
# 	 Fract: 0.999 'No Complication'
#
# OPTIME
# 	 Column detected numeric.
# 	 Number NaN: 3
#
# ORGSPCSSI
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.998 'No Complication'
# 	 Fract: 0.002 'Organ/Space SSI'
#
# OSSIPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.002 'Yes'
#
# OTHBLEED
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.992 'No Complication'
# 	 Fract: 0.008 'Transfusions/Intraop/Postop'
#
# OTHDVT
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Fract: 0.001 'DVT Requiring Therap'
# 	 Fract: 0.003 'DVT Requiring Therapy'
# 	 Fract: 0.996 'No Complication'
#
# OTHERCPT1
# 	 Forced categorical based on name match.
# 	 Encoding 602 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 602 enums.
#
# OTHERCPT10
# 	 Forced categorical based on name match.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.500 '27691.0'
# 	 Fract: 0.500 '28270.0'
#
# OTHERCPT2
# 	 Forced categorical based on name match.
# 	 Encoding 449 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 449 enums.
#
# OTHERCPT3
# 	 Forced categorical based on name match.
# 	 Encoding 203 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 203 enums.
#
# OTHERCPT4
# 	 Forced categorical based on name match.
# 	 Encoding 120 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 120 enums.
#
# OTHERCPT5
# 	 Forced categorical based on name match.
# 	 Encoding 77 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 77 enums.
#
# OTHERCPT6
# 	 Forced categorical based on name match.
# 	 Encoding 41 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 41 enums.
#
# OTHERCPT7
# 	 Forced categorical based on name match.
# 	 Encoding 18 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.050 '20900.0'
# 	 Fract: 0.050 '20926.0'
# 	 Fract: 0.050 '27606.0'
# 	 Fract: 0.050 '27625.0'
# 	 Fract: 0.050 '27687.0'
# 	 Fract: 0.050 '28120.0'
# 	 Fract: 0.050 '28208.0'
# 	 Fract: 0.100 '28232.0'
# 	 Fract: 0.150 '28285.0'
# 	 Fract: 0.050 '28300.0'
# 	 Fract: 0.050 '28304.0'
# 	 Fract: 0.050 '28306.0'
# 	 Fract: 0.050 '28308.0'
# 	 Fract: 0.050 '29515.0'
# 	 Fract: 0.050 '64450.0'
# 	 Fract: 0.050 '90471.0'
# 	 Fract: 0.050 '97605.0'
#
# OTHERCPT8
# 	 Forced categorical based on name match.
# 	 Encoding 9 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.125 '27640.0'
# 	 Fract: 0.125 '27687.0'
# 	 Fract: 0.125 '27690.0'
# 	 Fract: 0.125 '27871.0'
# 	 Fract: 0.125 '28208.0'
# 	 Fract: 0.125 '28285.0'
# 	 Fract: 0.125 '28290.0'
# 	 Fract: 0.125 '28306.0'
#
# OTHERCPT9
# 	 Forced categorical based on name match.
# 	 Encoding 6 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.167 '27698.0'
# 	 Fract: 0.167 '28208.0'
# 	 Fract: 0.167 '28285.0'
# 	 Fract: 0.167 '28300.0'
# 	 Fract: 0.333 '28308.0'
#
# OTHERPROC1
# 	 Column detected categorical.
# 	 Encoding 473 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 473 enums.
#
# OTHERPROC10
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.500 'CAPSUL MTTARPHLNGL JT +-TENORRHAPHY EA JT SPX'
# 	 Fract: 0.500 'TR/TRNSPL 1 TDN W/MUSC REDIRION/REROUTING DP'
#
# OTHERPROC2
# 	 Column detected categorical.
# 	 Encoding 355 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 355 enums.
#
# OTHERPROC3
# 	 Column detected categorical.
# 	 Encoding 232 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 232 enums.
#
# OTHERPROC4
# 	 Column detected categorical.
# 	 Encoding 132 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 132 enums.
#
# OTHERPROC5
# 	 Column detected categorical.
# 	 Encoding 80 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 80 enums.
#
# OTHERPROC6
# 	 Column detected categorical.
# 	 Encoding 41 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 41 enums.
#
# OTHERPROC7
# 	 Column detected categorical.
# 	 Encoding 18 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.050 'APPLICATION SHORT LEG SPLINT CALF FOOT'
# 	 Fract: 0.050 'ARTHROTOMY W/SYNOVECTOMY ANKLE'
# 	 Fract: 0.050 'BONE GRAFT ANY DONOR AREA MINOR/SMALL'
# 	 Fract: 0.150 'CORRECTION HAMMERTOE'
# 	 Fract: 0.050 'GASTROCNEMIUS RECESSION'
# 	 Fract: 0.050 'IMADM PRQ ID SUBQ/IM NJXS 1 VACCINE'
# 	 Fract: 0.050 'INJECTION ANES OTHER PERIPHERAL NERVE/BRANCH'
# 	 Fract: 0.050 'NEG PRESS WND THER </EQUAL 50 SQ CM'
# 	 Fract: 0.050 'OSTEOT W/WO LNGTH SHRT/CORRJ 1ST METAR'
# 	 Fract: 0.050 'OSTEOT W/WO LNGTH SHRT/CORRJ METAR XCP 1ST EA'
# 	 Fract: 0.050 'OSTEOTOMY CALCANEUS +-INTERNAL FIXATION'
# 	 Fract: 0.050 'OSTEOTOMY TARSAL BONES OTH/THN CALCANEUS/TALUS'
# 	 Fract: 0.050 'PRTL EXC B1 TALUS/CALCANEUS'
# 	 Fract: 0.050 'REPAIR TENDON EXTENSOR FOOT 1/2 EACH TENDON'
# 	 Fract: 0.050 'TENOTOMY PRQ ACHILLES TENDON SPX GENERAL ANES'
# 	 Fract: 0.050 'TISSUE GRAFTS OTHER'
# 	 Fract: 0.100 'TX OPN TDN FLXR TOE 1 TDN SPX'
#
# OTHERPROC8
# 	 Column detected categorical.
# 	 Encoding 9 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.125 'ARTHRODESIS TIBIOFIBULAR JOINT PROXIMAL/DISTAL'
# 	 Fract: 0.125 'CORRECTION HAMMERTOE'
# 	 Fract: 0.125 'CORRJ HALLUX VALGUS W/WO SESMDC SMPL EXOSTECTOMY'
# 	 Fract: 0.125 'GASTROCNEMIUS RECESSION'
# 	 Fract: 0.125 'OSTEOT W/WO LNGTH SHRT/CORRJ 1ST METAR'
# 	 Fract: 0.125 'PARTIAL EXCISION BONE TIBIA'
# 	 Fract: 0.125 'REPAIR TENDON EXTENSOR FOOT 1/2 EACH TENDON'
# 	 Fract: 0.125 'TR/TRNSPL 1 TDN W/MUSC REDIRION/REROUTING SUPFC'
#
# OTHERPROC9
# 	 Column detected categorical.
# 	 Encoding 7 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.167 'CORRECTION HAMMERTOE'
# 	 Fract: 0.167 'OSTEOT +-LNGTH SHRT/CORRJ METAR XCP 1ST EA'
# 	 Fract: 0.167 'OSTEOT W/WO LNGTH SHRT/CORRJ METAR XCP 1ST EA'
# 	 Fract: 0.167 'OSTEOTOMY CALCANEUS +-INTERNAL FIXATION'
# 	 Fract: 0.167 'REPAIR SECONDARY DISRUPTED LIGAMENT ANKLE COLTRL'
# 	 Fract: 0.167 'REPAIR TENDON EXTENSOR FOOT 1/2 EACH TENDON'
#
# OTHERWRVU1
# 	 Column detected numeric.
# 	 Number NaN: 14334
#
# OTHERWRVU10
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.500 '10.49'
# 	 Fract: 0.500 '4.93'
#
# OTHERWRVU2
# 	 Column detected numeric.
# 	 Number NaN: 17729
#
# OTHERWRVU3
# 	 Column detected numeric.
# 	 Number NaN: 18830
#
# OTHERWRVU4
# 	 Column detected numeric.
# 	 Number NaN: 19240
#
# OTHERWRVU5
# 	 Column detected numeric.
# 	 Number NaN: 19408
#
# OTHERWRVU6
# 	 Column detected numeric.
# 	 Number NaN: 19476
#
# OTHERWRVU7
# 	 Column detected numeric.
# 	 Number NaN: 19513
#
# OTHERWRVU8
# 	 Column detected categorical.
# 	 Encoding 9 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.125 '12.24'
# 	 Fract: 0.125 '4.51'
# 	 Fract: 0.125 '5.62'
# 	 Fract: 0.125 '5.83'
# 	 Fract: 0.125 '6.0'
# 	 Fract: 0.125 '6.41'
# 	 Fract: 0.125 '9.17'
# 	 Fract: 0.125 '9.54'
#
# OTHERWRVU9
# 	 Column detected categorical.
# 	 Encoding 6 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.167 '4.51'
# 	 Fract: 0.333 '5.48'
# 	 Fract: 0.167 '5.62'
# 	 Fract: 0.167 '9.61'
# 	 Fract: 0.167 '9.73'
#
# OTHGRAFL
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.000 'Graft/Prosthesis/Flap Failure'
# 	 Fract: 1.000 'No Complication'
#
# OTHSESHOCK
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.999 'No Complication'
# 	 Fract: 0.001 'Septic Shock'
#
# OTHSYSEP
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.996 'No Complication'
# 	 Fract: 0.004 'Sepsis'
#
# OUPNEUMO
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.996 'No Complication'
# 	 Fract: 0.004 'Pneumonia'
#
# PACKS
# 	 Column detected numeric.
# 	 Number NaN: 14336
#
# PARA
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.003 'Yes'
#
# PGY
# 	 Column detected numeric.
# 	 Number NaN: 14515
#
# PNAPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.001 'Yes'
#
# PODIAG
# 	 Forced categorical based on name match.
# 	 Encoding 499 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 499 enums.
#
# PODIAG10
# 	 Forced categorical based on name match.
# 	 Encoding 125 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 125 enums.
#
# PODIAGTX
# 	 Forced categorical based on name match.
# 	 Encoding 507 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 507 enums.
#
# PODIAGTX10
# 	 Forced categorical based on name match.
# 	 Encoding 125 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 125 enums.
#
# PODIAG_OTHER
# 	 Forced categorical based on name match.
# 	 Encoding 26 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 26 enums.
#
# PODIAG_OTHER10
# 	 Forced categorical based on name match.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 'T88.6XXA'
#
# PRALBUM
# 	 Column detected numeric.
# 	 Number NaN: 14636
#
# PRALKPH
# 	 Column detected numeric.
# 	 Number NaN: 14683
#
# PRBILI
# 	 Column detected numeric.
# 	 Number NaN: 14718
#
# PRBUN
# 	 Column detected numeric.
# 	 Number NaN: 8181
#
# PRCREAT
# 	 Column detected numeric.
# 	 Number NaN: 7793
#
# PREGNANCY
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.002 'Yes'
#
# PRHCT
# 	 Column detected numeric.
# 	 Number NaN: 6902
#
# PRINR
# 	 Column detected numeric.
# 	 Number NaN: 13314
#
# PRNCPTX
# 	 Forced categorical based on name match.
# 	 Encoding 104 enumerations:
# 	 Skipping due to 105 enums.
#
# PROPER30
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.026 'Yes'
#
# PRPLATE
# 	 Column detected numeric.
# 	 Number NaN: 7154
#
# PRPT
# 	 Column detected numeric.
# 	 Number NaN: 17883
#
# PRPTT
# 	 Column detected numeric.
# 	 Number NaN: 14983
#
# PRSEPIS
# 	 Column detected categorical.
# 	 Encoding 5 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.975 'None'
# 	 Fract: 0.019 'SIRS'
# 	 Fract: 0.005 'Sepsis'
# 	 Fract: 0.001 'Septic Shock'
#
# PRSGOT
# 	 Column detected numeric.
# 	 Number NaN: 14568
#
# PRSODM
# 	 Column detected numeric.
# 	 Number NaN: 7798
#
# PRVPCI
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.032 'Yes'
#
# PRVPCS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.025 'Yes'
#
# PRWBC
# 	 Column detected numeric.
# 	 Number NaN: 7126
#
# PULEMBOL
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.997 'No Complication'
# 	 Fract: 0.003 'Pulmonary Embolism'
#
# QUAD
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.001 'Yes'
#
# RACE_NEW
# 	 Column detected categorical.
# 	 Encoding 8 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.009 'American Indian or Alaska Native'
# 	 Fract: 0.018 'Asian'
# 	 Fract: 0.095 'Black or African American'
# 	 Fract: 0.004 'Native Hawaiian or Pacific Islander'
# 	 Fract: 0.050 'Unknown'
# 	 Fract: 0.160 'Unknown/Not Reported'
# 	 Fract: 0.664 'White'
#
# RADIO
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.001 'Yes'
#
# RBC
# 	 Forced continuous based on name match.
# 	 Number NaN: 17615
#
# READMISSION
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.044 'Yes'
#
# READMISSION1
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.027 'Yes'
#
# READMISSION2
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.002 'Yes'
#
# READMISSION3
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
#
# READMISSION4
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
#
# READMISSION5
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
#
# READMPODAYS1
# 	 Column detected numeric.
# 	 Number NaN: 19186
#
# READMPODAYS2
# 	 Column detected numeric.
# 	 Number NaN: 19521
#
# READMPODAYS3
# 	 Skipping because there is only 1 value.
#
# READMPODAYS4
# 	 Skipping because there is only 1 value.
#
# READMPODAYS5
# 	 Skipping because there is only 1 value.
#
# READMRELATED1
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.650 'Yes'
#
# READMRELATED2
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.500 'Yes'
#
# READMRELATED3
# 	 Skipping because there is only 1 value.
#
# READMRELATED4
# 	 Skipping because there is only 1 value.
#
# READMRELATED5
# 	 Skipping because there is only 1 value.
#
# READMRELICD101
# 	 Forced categorical based on name match.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 'S89.399A'
#
# READMRELICD102
# 	 Skipping because there is only 1 value.
#
# READMRELICD103
# 	 Skipping because there is only 1 value.
#
# READMRELICD104
# 	 Skipping because there is only 1 value.
#
# READMRELICD105
# 	 Skipping because there is only 1 value.
#
# READMRELICD91
# 	 Forced categorical based on name match.
# 	 Encoding 44 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 44 enums.
#
# READMRELICD92
# 	 Forced categorical based on name match.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.500 '560.1'
# 	 Fract: 0.500 '780.6'
#
# READMRELICD93
# 	 Skipping because there is only 1 value.
#
# READMRELICD94
# 	 Skipping because there is only 1 value.
#
# READMRELICD95
# 	 Skipping because there is only 1 value.
#
# READMSUSPREASON1
# 	 Column detected categorical.
# 	 Encoding 18 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.005 'Acute Renal Failure'
# 	 Fract: 0.035 'DVT Requiring Therapy'
# 	 Fract: 0.149 'Deep Incisional SSI'
# 	 Fract: 0.005 'Graft/Prosthesis/Flap Failure'
# 	 Fract: 0.015 'Myocardial Infarction'
# 	 Fract: 0.050 'Organ/Space SSI'
# 	 Fract: 0.005 'Other (list ICD 10 code)'
# 	 Fract: 0.353 'Other (list ICD 9 code)'
# 	 Fract: 0.030 'Pneumonia'
# 	 Fract: 0.090 'Pulmonary Embolism'
# 	 Fract: 0.015 'Sepsis'
# 	 Fract: 0.015 'Septic Shock'
# 	 Fract: 0.119 'Superficial Incisional SSI'
# 	 Fract: 0.005 'Unplanned Intubation'
# 	 Fract: 0.030 'Urinary Tract Infection'
# 	 Fract: 0.015 'Vein Thrombosis Requiring Therapy'
# 	 Fract: 0.065 'Wound Disruption'
#
# READMSUSPREASON2
# 	 Column detected categorical.
# 	 Encoding 6 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.167 'DVT Requiring Therapy'
# 	 Fract: 0.167 'Deep Incisional SSI'
# 	 Fract: 0.333 'Other (list ICD 9 code)'
# 	 Fract: 0.167 'Superficial Incisional SSI'
# 	 Fract: 0.167 'Wound Disruption'
#
# READMSUSPREASON3
# 	 Skipping because there is only 1 value.
#
# READMSUSPREASON4
# 	 Skipping because there is only 1 value.
#
# READMSUSPREASON5
# 	 Skipping because there is only 1 value.
#
# READMUNRELICD101
# 	 Forced categorical based on name match.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.333 'C78.5'
# 	 Fract: 0.333 'K29.0'
# 	 Fract: 0.333 'R62.7'
#
# READMUNRELICD102
# 	 Skipping because there is only 1 value.
#
# READMUNRELICD103
# 	 Skipping because there is only 1 value.
#
# READMUNRELICD104
# 	 Skipping because there is only 1 value.
#
# READMUNRELICD105
# 	 Skipping because there is only 1 value.
#
# READMUNRELICD91
# 	 Forced categorical based on name match.
# 	 Encoding 52 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 52 enums.
#
# READMUNRELICD92
# 	 Forced categorical based on name match.
# 	 Encoding 6 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.200 '291.81'
# 	 Fract: 0.200 '401.9'
# 	 Fract: 0.200 '486.0'
# 	 Fract: 0.200 '586.0'
# 	 Fract: 0.200 '8.45'
#
# READMUNRELICD93
# 	 Skipping because there is only 1 value.
#
# READMUNRELICD94
# 	 Skipping because there is only 1 value.
#
# READMUNRELICD95
# 	 Skipping because there is only 1 value.
#
# READMUNRELSUSP1
# 	 Column detected categorical.
# 	 Encoding 9 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.012 'Acute Renal Failure'
# 	 Fract: 0.012 'Deep Incisional SSI'
# 	 Fract: 0.012 'Myocardial Infarction'
# 	 Fract: 0.012 'Organ/Space SSI'
# 	 Fract: 0.061 'Other (list ICD10 code)'
# 	 Fract: 0.793 'Other (list ICD9 code)'
# 	 Fract: 0.049 'Pneumonia'
# 	 Fract: 0.049 'Urinary Tract Infection'
#
# READMUNRELSUSP2
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 'Other (list ICD9 code)'
#
# READMUNRELSUSP3
# 	 Skipping because there is only 1 value.
#
# READMUNRELSUSP4
# 	 Skipping because there is only 1 value.
#
# READMUNRELSUSP5
# 	 Skipping because there is only 1 value.
#
# REINTUB
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.998 'No Complication'
# 	 Fract: 0.002 'Unplanned Intubation'
#
# RENAFAIL
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.002 'Yes'
#
# RENAINSF
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.999 'No Complication'
# 	 Fract: 0.001 'Progressive Renal Insufficiency'
#
# REOPERATION
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.020 'Yes'
#
# REOPERATION1
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.015 'Yes'
#
# REOPERATION2
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.003 'Yes'
#
# REOPERATION3
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.001 'Yes'
#
# REOPOR1ICD101
# 	 Forced categorical based on name match.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.500 'T81.4XXA'
# 	 Fract: 0.500 'Z86.31'
#
# REOPOR2CPT1
# 	 Forced categorical based on name match.
# 	 Encoding 18 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.222 '10180.0'
# 	 Fract: 0.037 '11012.0'
# 	 Fract: 0.111 '11042.0'
# 	 Fract: 0.074 '11043.0'
# 	 Fract: 0.074 '11044.0'
# 	 Fract: 0.037 '11045.0'
# 	 Fract: 0.037 '11046.0'
# 	 Fract: 0.037 '12036.0'
# 	 Fract: 0.037 '13160.0'
# 	 Fract: 0.037 '14021.0'
# 	 Fract: 0.074 '20680.0'
# 	 Fract: 0.037 '27610.0'
# 	 Fract: 0.037 '27792.0'
# 	 Fract: 0.037 '27827.0'
# 	 Fract: 0.037 '27880.0'
# 	 Fract: 0.037 '31610.0'
# 	 Fract: 0.037 '97605.0'
#
# REOPOR2ICD101
# 	 Skipping because there is only 1 value.
#
# REOPOR2ICD91
# 	 Forced categorical based on name match.
# 	 Encoding 12 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.091 '41.11'
# 	 Fract: 0.045 '733.8'
# 	 Fract: 0.045 '824.5'
# 	 Fract: 0.045 '958.92'
# 	 Fract: 0.045 '996.49'
# 	 Fract: 0.227 '996.67'
# 	 Fract: 0.045 '997.6'
# 	 Fract: 0.045 '998.3'
# 	 Fract: 0.091 '998.32'
# 	 Fract: 0.045 '998.5'
# 	 Fract: 0.273 '998.59'
#
# REOPORCPT1
# 	 Forced categorical based on name match.
# 	 Encoding 93 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 93 enums.
#
# REOPORICD91
# 	 Forced categorical based on name match.
# 	 Encoding 65 enumerations:
# 	 Found enumerated NaNs...
# 	 Skipping due to 65 enums.
#
# RESTPAIN
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.010 'Yes'
#
# RETOR2PODAYS
# 	 Column detected numeric.
# 	 Number NaN: 19506
#
# RETOR2RELATED
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.111 'No'
# 	 Fract: 0.037 'Unknown'
# 	 Fract: 0.852 'Yes'
#
# RETORPODAYS
# 	 Column detected numeric.
# 	 Number NaN: 19329
#
# RETORRELATED
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.216 'No'
# 	 Fract: 0.034 'Unknown'
# 	 Fract: 0.750 'Yes'
#
# RETURNOR
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# 	 Fract: 0.016 'Yes'
#
# SDISDT
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.378 '2008.0'
# 	 Fract: 0.618 '2009.0'
# 	 Fract: 0.004 '2010.0'
#
# SEPSHOCKPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.000 'Yes'
#
# SEPSISPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.002 'Yes'
#
# SEX
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.516 'female'
# 	 Fract: 0.484 'male'
#
# SMOKE
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# 	 Fract: 0.228 'Yes'
#
# SSSIPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.001 'Yes'
#
# STEROID
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# 	 Fract: 0.018 'Yes'
#
# STILLINHOSP
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.005 'Yes'
#
# STOODAY
# 	 Column detected numeric.
# 	 Number NaN: 17603
#
# SUPINFEC
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.990 'No Complication'
# 	 Fract: 0.010 'Superficial Incisional SSI'
#
# SURGANE
# 	 Column detected numeric.
# 	 Number NaN: 13114
#
# SURGSPEC
# 	 Skipping because there is only 1 value.
#
# TOTHLOS
# 	 Column detected numeric.
# 	 Number NaN: 11
#
# TOTSLOS
# 	 Column detected numeric.
# 	 Number NaN: 17603
#
# TRANSFUS
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# 	 Fract: 0.004 'Yes'
#
# TRANST
# 	 Column detected categorical.
# 	 Encoding 11 enumerations:
# 	 Fract: 0.002 'Acute Care Hospital'
# 	 Fract: 0.095 'Admitted directly from home'
# 	 Fract: 0.001 'Chronic Care Facility'
# 	 Fract: 0.011 'From acute care hospital inpatient'
# 	 Fract: 0.856 'Not transferred (admitted from home)'
# 	 Fract: 0.011 'Nursing home - Chronic care - Intermediate care'
# 	 Fract: 0.000 'Other'
# 	 Fract: 0.020 'Outside emergency department'
# 	 Fract: 0.003 'Transfer from other'
# 	 Fract: 0.001 'Unknown'
# 	 Fract: 0.000 'VA Acute Care Hospital'
#
# TUMORCNS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.000 'Yes'
#
# TYPEINTOC
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 1.000 'Unplanned Intubation'
#
# UNPLANNEDREADMISSION1
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.883 'Yes'
#
# UNPLANNEDREADMISSION2
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 1.000 'Yes'
#
# UNPLANNEDREADMISSION3
# 	 Skipping because there is only 1 value.
#
# UNPLANNEDREADMISSION4
# 	 Skipping because there is only 1 value.
#
# UNPLANNEDREADMISSION5
# 	 Skipping because there is only 1 value.
#
# UNPLANREADMISSION
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.525 'Yes'
#
# URNINFEC
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.993 'No Complication'
# 	 Fract: 0.007 'Urinary Tract Infection'
#
# UTIPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.002 'Yes'
#
# VENTILAT
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# 	 Fract: 0.001 'Yes'
#
# VENTPATOS
# 	 Column detected categorical.
# 	 Encoding 3 enumerations:
# 	 Found enumerated NaNs...
# 	 Binary response; returning only Yes
# 	 Fract: 0.001 'Yes'
#
# WEIGHT
# 	 Column detected numeric.
# 	 Number NaN: 584
#
# WNDCLAS
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Fract: 0.932 '1-Clean'
# 	 Fract: 0.025 '2-Clean/Contaminated'
# 	 Fract: 0.021 '3-Contaminated'
# 	 Fract: 0.022 '4-Dirty/Infected'
#
# WNDINF
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# 	 Fract: 0.048 'Yes'
#
# WNDINFD
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Fract: 0.004 'Deep Incisional SSI'
# 	 Fract: 0.996 'No Complication'
#
# WORKRVU
# 	 Column detected numeric.
# 	 Number NaN: 0
#
# WOUND_CLOSURE
# 	 Column detected categorical.
# 	 Encoding 4 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.989 'All layers of incision (deep and superficial) fully closed'
# 	 Fract: 0.007 'No layers of incision are surgically closed'
# 	 Fract: 0.004 'Only deep layers closed; superficial left open'
#
# WTLOSS
# 	 Column detected categorical.
# 	 Encoding 2 enumerations:
# 	 Binary response; returning only Yes
# 	 Fract: 0.001 'Yes'
#
# YRDEATH
# 	 Column detected categorical.
# 	 Encoding 9 enumerations:
# 	 Found enumerated NaNs...
# 	 Fract: 0.019 '2008.0'
# 	 Fract: 0.037 '2009.0'
# 	 Fract: 0.037 '2010.0'
# 	 Fract: 0.111 '2011.0'
# 	 Fract: 0.241 '2012.0'
# 	 Fract: 0.148 '2013.0'
# 	 Fract: 0.352 '2014.0'
# 	 Fract: 0.056 '2015.0'

# %% [markdown]
# Ok, let's save this cleaned up data to disk. Note that there are still missing values for numeric variables.

# %%
cdf.to_pickle(mungedFileName)

# %%
# cdf['intercept'] = 1.0
# X = cdf.copy()
# X.drop('READMISSION1-Yes',1)

# imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
# imp.fit(X)
# X = imp.transform(X) 
# X.shape

# logistic = linear_model.LogisticRegression(C=1e5, verbose=True)
# logistic.fit(X, cdf['READMISSION1-Yes'])
